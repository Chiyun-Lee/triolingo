# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "data/Unihan_Readings.txt", sep = "\t", comment = "#",
    names = ["Unicode", "col1", "col2"]
).pivot(index = "Unicode", columns = "col1", values = "col2")

df.columns.name = None

columns_of_interest = [
    "kDefinition", "kHangul", "kKorean",
    "kMandarin",
    "kJapanese", "kJapaneseOn",
]

df = df[columns_of_interest].reset_index()

df["Character"]   = df.Unicode.apply(lambda x: chr(int(x.replace('U+', ''), 16)))

df["kMandarin"]   = df.kMandarin.str.split(" ").str[0]
df["kHangul"]     = df.kHangul.str.split(" ").str[0].str.split(":").str[0]
df["kKorean"]     = df.kKorean.str.split(" ").str[0]
df["kJapanese"]   = df.kJapanese.str.split(" ").str[0]
df["kJapaneseOn"] = df.kJapaneseOn.str.split(" ").str[0]

# %%
pd.set_option("display.max_rows", None)

minimal_columns = [
    "kDefinition", "Character", "kMandarin", "kHangul", "kKorean", "kJapanese", "kJapaneseOn"
]

df = df[minimal_columns].dropna().reset_index(drop=True)

df.head()
# Out:
#                                          kDefinition Character kMandarin  \
# 0                                  one; a, an; alone         一        yī
# 1    male adult; robust, vigorous; 4th heavenly stem         丁      dīng
# 2                                              seven         七        qī
# 3                          ten thousand; innumerable         万       wàn
# 4  unit of length equal 3.3 meters; gentleman, ma...         丈     zhàng
#
#   kHangul kKorean kJapanese kJapaneseOn
# 0       일      IL        イチ        ICHI
# 1       정    CENG       チョウ         TEI
# 2       칠    CHIL        シチ      SHICHI
# 3       만     MAN        マン         MAN
# 4       장    CANG       ジョウ         JOU

# %%
HANGUL_BASE = 0xAC00
CHOSUNG_BASE = 588
JUNGSUNG_BASE = 28

CHOSUNG_LIST = [
    'ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ',
    'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ',
    'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ'
]

JUNGSUNG_LIST = [
    'ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ',
    'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ',
    'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ'
]

JONGSUNG_LIST = [
    '', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ',
    'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ',
    'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ',
    'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ'
]

def decompose_hangul(syllable):
    code = ord(syllable)
    if not (0xAC00 <= code <= 0xD7A3):
        return (syllable, '', '')  # Not a Hangul syllable

    offset = code - HANGUL_BASE
    chosung_index = offset // CHOSUNG_BASE
    jungsung_index = (offset % CHOSUNG_BASE) // JUNGSUNG_BASE
    jongsung_index = offset % JUNGSUNG_BASE

    return (
        CHOSUNG_LIST[chosung_index],
        JUNGSUNG_LIST[jungsung_index],
        JONGSUNG_LIST[jongsung_index]
    )

df["decomposed_hangul"] = df.kHangul.apply(decompose_hangul)
df[["kHangul", "kKorean", "decomposed_hangul"]].value_counts()
# Out:
# kHangul  kKorean  decomposed_hangul
# 구        KWU      (ㄱ, ㅜ, )             101
# 기        KI       (ㄱ, ㅣ, )              87
# 비        PI       (ㅂ, ㅣ, )              84
# 사        SA       (ㅅ, ㅏ, )              78
# 유        YU       (ㅇ, ㅠ, )              76
# 조        CO       (ㅈ, ㅗ, )              75
# 수        SWU      (ㅅ, ㅜ, )              74
# 전        CEN      (ㅈ, ㅓ, ㄴ)             73
# 정        CENG     (ㅈ, ㅓ, ㅇ)             67
# 부        PWU      (ㅂ, ㅜ, )              63
# 경        KYENG    (ㄱ, ㅕ, ㅇ)             63
# 고        KO       (ㄱ, ㅗ, )              63
# 소        SO       (ㅅ, ㅗ, )              59
# 주        CWU      (ㅈ, ㅜ, )              58
# 도        TO       (ㄷ, ㅗ, )              57
# 장        CANG     (ㅈ, ㅏ, ㅇ)             55
# 호        HO       (ㅎ, ㅗ, )              53
# 초        CHO      (ㅊ, ㅗ, )              51
# 추        CHWU     (ㅊ, ㅜ, )              50
# 자        CA       (ㅈ, ㅏ, )              49
# 지        CI       (ㅈ, ㅣ, )              49
# 저        CE       (ㅈ, ㅓ, )              46
# 시        SI       (ㅅ, ㅣ, )              46
# 오        O        (ㅇ, ㅗ, )              46
# 가        KA       (ㄱ, ㅏ, )              43
# 서        SE       (ㅅ, ㅓ, )              42
# 선        SEN      (ㅅ, ㅓ, ㄴ)             42
# 교        KYO      (ㄱ, ㅛ, )              41
# 치        CHI      (ㅊ, ㅣ, )              40
# 요        YO       (ㅇ, ㅛ, )              40
# 연        YEN      (ㅇ, ㅕ, ㄴ)             40
# 방        PANG     (ㅂ, ㅏ, ㅇ)             39
# 강        KANG     (ㄱ, ㅏ, ㅇ)             39
# 리        LI       (ㄹ, ㅣ, )              39
# 포        PHO      (ㅍ, ㅗ, )              39
# 진        CIN      (ㅈ, ㅣ, ㄴ)             39
# 우        WU       (ㅇ, ㅜ, )              38
# 예        YEY      (ㅇ, ㅖ, )              37
# 위        WI       (ㅇ, ㅟ, )              37
# 상        SANG     (ㅅ, ㅏ, ㅇ)             37
# 제        CEY      (ㅈ, ㅔ, )              37
# 모        MO       (ㅁ, ㅗ, )              36
# 창        CHANG    (ㅊ, ㅏ, ㅇ)             35
# 원        WEN      (ㅇ, ㅝ, ㄴ)             35
# 미        MI       (ㅁ, ㅣ, )              34
# 이        I        (ㅇ, ㅣ, )              33
# 순        SWUN     (ㅅ, ㅜ, ㄴ)             33
# 준        CWUN     (ㅈ, ㅜ, ㄴ)             33
# 계        KYEY     (ㄱ, ㅖ, )              33
# 반        PAN      (ㅂ, ㅏ, ㄴ)             32
# 신        SIN      (ㅅ, ㅣ, ㄴ)             32
# 분        PWUN     (ㅂ, ㅜ, ㄴ)             32
# 영        YENG     (ㅇ, ㅕ, ㅇ)             32
# 현        HYEN     (ㅎ, ㅕ, ㄴ)             32
# 양        YANG     (ㅇ, ㅑ, ㅇ)             31
# 천        CHEN     (ㅊ, ㅓ, ㄴ)             31
# 희        HUY      (ㅎ, ㅢ, )              31
# 아        A        (ㅇ, ㅏ, )              31
# 규        KYU      (ㄱ, ㅠ, )              30
# 애        AY       (ㅇ, ㅐ, )              30
# 동        TONG     (ㄷ, ㅗ, ㅇ)             29
# 간        KAN      (ㄱ, ㅏ, ㄴ)             29
# 황        HWANG    (ㅎ, ㅘ, ㅇ)             29
# 관        KWAN     (ㄱ, ㅘ, ㄴ)             29
# 해        HAY      (ㅎ, ㅐ, )              29
# 파        PHA      (ㅍ, ㅏ, )              28
# 용        YONG     (ㅇ, ㅛ, ㅇ)             28
# 거        KE       (ㄱ, ㅓ, )              28
# 적        CEK      (ㅈ, ㅓ, ㄱ)             28
# 회        HOY      (ㅎ, ㅚ, )              28
# 만        MAN      (ㅁ, ㅏ, ㄴ)             28
# 타        THA      (ㅌ, ㅏ, )              27
# 환        HWAN     (ㅎ, ㅘ, ㄴ)             27
# 령        LYENG    (ㄹ, ㅕ, ㅇ)             27
# 표        PHYO     (ㅍ, ㅛ, )              27
# 려        LYE      (ㄹ, ㅕ, )              27
# 무        MWU      (ㅁ, ㅜ, )              26
# 감        KAM      (ㄱ, ㅏ, ㅁ)             26
# 당        TANG     (ㄷ, ㅏ, ㅇ)             26
# 개        KAY      (ㄱ, ㅐ, )              26
# 의        UY       (ㅇ, ㅢ, )              26
# 단        TAN      (ㄷ, ㅏ, ㄴ)             26
# 빈        PIN      (ㅂ, ㅣ, ㄴ)             26
# 담        TAM      (ㄷ, ㅏ, ㅁ)             26
# 공        KONG     (ㄱ, ㅗ, ㅇ)             26
# 인        IN       (ㅇ, ㅣ, ㄴ)             25
# 복        POK      (ㅂ, ㅗ, ㄱ)             25
# 종        CONG     (ㅈ, ㅗ, ㅇ)             24
# 한        HAN      (ㅎ, ㅏ, ㄴ)             24
# 참        CHAM     (ㅊ, ㅏ, ㅁ)             24
# 형        HYENG    (ㅎ, ㅕ, ㅇ)             24
# 근        KUN      (ㄱ, ㅡ, ㄴ)             24
# 박        PAK      (ㅂ, ㅏ, ㄱ)             24
# 병        PYENG    (ㅂ, ㅕ, ㅇ)             23
# 찬        CHAN     (ㅊ, ㅏ, ㄴ)             23
# 과        KWA      (ㄱ, ㅘ, )              23
# 배        PAY      (ㅂ, ㅐ, )              22
# 광        KWANG    (ㄱ, ㅘ, ㅇ)             22
# 매        MAY      (ㅁ, ㅐ, )              22
# 악        AK       (ㅇ, ㅏ, ㄱ)             22
# 척        CHEK     (ㅊ, ㅓ, ㄱ)             21
# 곤        KON      (ㄱ, ㅗ, ㄴ)             21
# 료        LYO      (ㄹ, ㅛ, )              21
# 하        HA       (ㅎ, ㅏ, )              21
# 탁        THAK     (ㅌ, ㅏ, ㄱ)             21
# 후        HWU      (ㅎ, ㅜ, )              21
# 석        SEK      (ㅅ, ㅓ, ㄱ)             20
# 차        CHA      (ㅊ, ㅏ, )              20
# 산        SAN      (ㅅ, ㅏ, ㄴ)             20
# 대        TAY      (ㄷ, ㅐ, )              20
# 완        WAN      (ㅇ, ㅘ, ㄴ)             20
# 효        HYO      (ㅎ, ㅛ, )              20
# 궤        KWEY     (ㄱ, ㅞ, )              20
# 보        PO       (ㅂ, ㅗ, )              20
# 민        MIN      (ㅁ, ㅣ, ㄴ)             20
# 화        HWA      (ㅎ, ㅘ, )              19
# 체        CHEY     (ㅊ, ㅔ, )              19
# 염        YEM      (ㅇ, ㅕ, ㅁ)             19
# 철        CHEL     (ㅊ, ㅓ, ㄹ)             19
# 견        KYEN     (ㄱ, ㅕ, ㄴ)             19
# 봉        PONG     (ㅂ, ㅗ, ㅇ)             19
# 류        LYU      (ㄹ, ㅠ, )              19
# 작        CAK      (ㅈ, ㅏ, ㄱ)             19
# 질        CIL      (ㅈ, ㅣ, ㄹ)             19
# 재        CAY      (ㅈ, ㅐ, )              19
# 설        SEL      (ㅅ, ㅓ, ㄹ)             19
# 항        HANG     (ㅎ, ㅏ, ㅇ)             19
# 련        LYEN     (ㄹ, ㅕ, ㄴ)             19
# 점        CEM      (ㅈ, ㅓ, ㅁ)             19
# 린        LIN      (ㄹ, ㅣ, ㄴ)             18
# 량        LYANG    (ㄹ, ㅑ, ㅇ)             18
# 편        PHYEN    (ㅍ, ㅕ, ㄴ)             18
# 필        PHIL     (ㅍ, ㅣ, ㄹ)             18
# 성        SENG     (ㅅ, ㅓ, ㅇ)             18
# 등        TUNG     (ㄷ, ㅡ, ㅇ)             17
# 태        THAY     (ㅌ, ㅐ, )              17
# 협        HYEP     (ㅎ, ㅕ, ㅂ)             17
# 취        CHWI     (ㅊ, ㅟ, )              17
# 은        UN       (ㅇ, ㅡ, ㄴ)             17
# 첨        CHEM     (ㅊ, ㅓ, ㅁ)             17
# 두        TWU      (ㄷ, ㅜ, )              17
# 건        KEN      (ㄱ, ㅓ, ㄴ)             16
# 함        HAM      (ㅎ, ㅏ, ㅁ)             16
# 금        KUM      (ㄱ, ㅡ, ㅁ)             16
# 옹        ONG      (ㅇ, ㅗ, ㅇ)             16
# 로        LO       (ㄹ, ㅗ, )              16
# 권        KWEN     (ㄱ, ㅝ, ㄴ)             16
# 망        MANG     (ㅁ, ㅏ, ㅇ)             16
# 각        KAK      (ㄱ, ㅏ, ㄱ)             16
# 온        ON       (ㅇ, ㅗ, ㄴ)             16
# 식        SIK      (ㅅ, ㅣ, ㄱ)             16
# 문        MWUN     (ㅁ, ㅜ, ㄴ)             15
# 첩        CHEP     (ㅊ, ㅓ, ㅂ)             15
# 와        WA       (ㅇ, ㅘ, )              15
# 총        CHONG    (ㅊ, ㅗ, ㅇ)             15
# 훈        HWUN     (ㅎ, ㅜ, ㄴ)             15
# 발        PAL      (ㅂ, ㅏ, ㄹ)             15
# 혜        HYEY     (ㅎ, ㅖ, )              15
# 면        MYEN     (ㅁ, ㅕ, ㄴ)             15
# 묘        MYO      (ㅁ, ㅛ, )              15
# 축        CHWUK    (ㅊ, ㅜ, ㄱ)             15
# 운        WUN      (ㅇ, ㅜ, ㄴ)             15
# 갈        KAL      (ㄱ, ㅏ, ㄹ)             15
# 섬        SEM      (ㅅ, ㅓ, ㅁ)             15
# 침        CHIM     (ㅊ, ㅣ, ㅁ)             15
# 어        E        (ㅇ, ㅓ, )              15
# 청        CHENG    (ㅊ, ㅓ, ㅇ)             14
# 명        MYENG    (ㅁ, ㅕ, ㅇ)             14
# 탄        THAN     (ㅌ, ㅏ, ㄴ)             14
# 패        PHAY     (ㅍ, ㅐ, )              14
# 채        CHAY     (ㅊ, ㅐ, )              14
# 폐        PHYEY    (ㅍ, ㅖ, )              14
# 암        AM       (ㅇ, ㅏ, ㅁ)             14
# 증        CUNG     (ㅈ, ㅡ, ㅇ)             14
# 뢰        LOY      (ㄹ, ㅚ, )              14
# 번        PEN      (ㅂ, ㅓ, ㄴ)             14
# 여        YE       (ㅇ, ㅕ, )              14
# 벽        PYEK     (ㅂ, ㅕ, ㄱ)             14
# 변        PYEN     (ㅂ, ㅕ, ㄴ)             13
# 괴        KOY      (ㄱ, ㅚ, )              13
# 심        SIM      (ㅅ, ㅣ, ㅁ)             13
# 역        YEK      (ㅇ, ㅕ, ㄱ)             13
# 언        EN       (ㅇ, ㅓ, ㄴ)             13
# 안        AN       (ㅇ, ㅏ, ㄴ)             13
# 마        MA       (ㅁ, ㅏ, )              13
# 약        YAK      (ㅇ, ㅑ, ㄱ)             13
# 앙        ANG      (ㅇ, ㅏ, ㅇ)             13
# 홍        HONG     (ㅎ, ㅗ, ㅇ)             13
# 노        NO       (ㄴ, ㅗ, )              12
# 격        KYEK     (ㄱ, ㅕ, ㄱ)             12
# 합        HAP      (ㅎ, ㅏ, ㅂ)             12
# 급        KUP      (ㄱ, ㅡ, ㅂ)             12
# 겸        KYEM     (ㄱ, ㅕ, ㅁ)             12
# 엄        EM       (ㅇ, ㅓ, ㅁ)             12
# 외        OY       (ㅇ, ㅚ, )              12
# 삽        SAP      (ㅅ, ㅏ, ㅂ)             12
# 노        LO       (ㄴ, ㅗ, )              12
# 절        CEL      (ㅈ, ㅓ, ㄹ)             12
# 숙        SWUK     (ㅅ, ㅜ, ㄱ)             12
# 섭        SEP      (ㅅ, ㅓ, ㅂ)             11
# 음        UM       (ㅇ, ㅡ, ㅁ)             11
# 임        IM       (ㅇ, ㅣ, ㅁ)             11
# 승        SUNG     (ㅅ, ㅡ, ㅇ)             11
# 불        PWUL     (ㅂ, ㅜ, ㄹ)             11
# 일        IL       (ㅇ, ㅣ, ㄹ)             11
# 범        PEM      (ㅂ, ㅓ, ㅁ)             11
# 력        LYEK     (ㄹ, ㅕ, ㄱ)             11
# 야        YA       (ㅇ, ㅑ, )              11
# 학        HAK      (ㅎ, ㅏ, ㄱ)             11
# 곡        KOK      (ㄱ, ㅗ, ㄱ)             11
# 극        KUK      (ㄱ, ㅡ, ㄱ)             11
# 돈        TON      (ㄷ, ㅗ, ㄴ)             11
# 최        CHOY     (ㅊ, ㅚ, )              11
# 독        TOK      (ㄷ, ㅗ, ㄱ)             11
# 루        LWU      (ㄹ, ㅜ, )              11
# 송        SONG     (ㅅ, ㅗ, ㅇ)             10
# 착        CHAK     (ㅊ, ㅏ, ㄱ)             10
# 피        PHI      (ㅍ, ㅣ, )              10
# 혼        HON      (ㅎ, ㅗ, ㄴ)             10
# 평        PHYENG   (ㅍ, ㅕ, ㅇ)             10
# 향        HYANG    (ㅎ, ㅑ, ㅇ)             10
# 액        AYK      (ㅇ, ㅐ, ㄱ)             10
# 국        KWUK     (ㄱ, ㅜ, ㄱ)             10
# 괄        KWAL     (ㄱ, ㅘ, ㄹ)             10
# 알        AL       (ㅇ, ㅏ, ㄹ)             10
# 책        CHAYK    (ㅊ, ㅐ, ㄱ)             10
# 우        YU       (ㅇ, ㅜ, )               9
# 판        PHAN     (ㅍ, ㅏ, ㄴ)              9
# 투        THWU     (ㅌ, ㅜ, )               9
# 접        CEP      (ㅈ, ㅓ, ㅂ)              9
# 흘        HUL      (ㅎ, ㅡ, ㄹ)              9
# 랑        LANG     (ㄹ, ㅏ, ㅇ)              9
# 달        TAL      (ㄷ, ㅏ, ㄹ)              9
# 몽        MONG     (ㅁ, ㅗ, ㅇ)              9
# 삼        SAM      (ㅅ, ㅏ, ㅁ)              9
# 휴        HYU      (ㅎ, ㅠ, )               9
# 세        SEY      (ㅅ, ㅔ, )               9
# 결        KYEL     (ㄱ, ㅕ, ㄹ)              9
# 검        KEM      (ㄱ, ㅓ, ㅁ)              9
# 곽        KWAK     (ㄱ, ㅘ, ㄱ)              9
# 촉        CHOK     (ㅊ, ㅗ, ㄱ)              9
# 통        THONG    (ㅌ, ㅗ, ㅇ)              9
# 휘        HWI      (ㅎ, ㅟ, )               9
# 좌        CWA      (ㅈ, ㅘ, )               9
# 잠        CAM      (ㅈ, ㅏ, ㅁ)              9
# 누        LWU      (ㄴ, ㅜ, )               8
# 균        KYUN     (ㄱ, ㅠ, ㄴ)              8
# 군        KWUN     (ㄱ, ㅜ, ㄴ)              8
# 왕        WANG     (ㅇ, ㅘ, ㅇ)              8
# 습        SUP      (ㅅ, ㅡ, ㅂ)              8
# 굉        KOYNG    (ㄱ, ㅚ, ㅇ)              8
# 니        NI       (ㄴ, ㅣ, )               8
# 혁        HYEK     (ㅎ, ㅕ, ㄱ)              8
# 쟁        CAYNG    (ㅈ, ㅐ, ㅇ)              8
# 목        MOK      (ㅁ, ㅗ, ㄱ)              8
# 륜        LYUN     (ㄹ, ㅠ, ㄴ)              8
# 례        LYEY     (ㄹ, ㅖ, )               8
# 람        LAM      (ㄹ, ㅏ, ㅁ)              8
# 록        LOK      (ㄹ, ㅗ, ㄱ)              8
# 란        LAN      (ㄹ, ㅏ, ㄴ)              8
# 라        LA       (ㄹ, ㅏ, )               8
# 둔        TWUN     (ㄷ, ㅜ, ㄴ)              8
# 흔        HUN      (ㅎ, ㅡ, ㄴ)              8
# 말        MAL      (ㅁ, ㅏ, ㄹ)              8
# 충        CHWUNG   (ㅊ, ㅜ, ㅇ)              8
# 처        CHE      (ㅊ, ㅓ, )               8
# 탕        THANG    (ㅌ, ㅏ, ㅇ)              8
# 빙        PING     (ㅂ, ㅣ, ㅇ)              8
# 익        IK       (ㅇ, ㅣ, ㄱ)              7
# 잔        CAN      (ㅈ, ㅏ, ㄴ)              7
# 나        LA       (ㄴ, ㅏ, )               7
# 백        PAYK     (ㅂ, ㅐ, ㄱ)              7
# 집        CIP      (ㅈ, ㅣ, ㅂ)              7
# 롱        LONG     (ㄹ, ㅗ, ㅇ)              7
# 퇴        THOY     (ㅌ, ㅚ, )               7
# 궁        KWUNG    (ㄱ, ㅜ, ㅇ)              7
# 굴        KWUL     (ㄱ, ㅜ, ㄹ)              7
# 렴        LYEM     (ㄹ, ㅕ, ㅁ)              7
# 찰        CHAL     (ㅊ, ㅏ, ㄹ)              7
# 확        HWAK     (ㅎ, ㅘ, ㄱ)              7
# 괘        KWAY     (ㄱ, ㅙ, )               7
# 막        MAK      (ㅁ, ㅏ, ㄱ)              7
# 맥        MAYK     (ㅁ, ㅐ, ㄱ)              7
# 훼        HWEY     (ㅎ, ㅞ, )               7
# 앵        AYNG     (ㅇ, ㅐ, ㅇ)              7
# 속        SOK      (ㅅ, ㅗ, ㄱ)              7
# 흡        HUP      (ㅎ, ㅡ, ㅂ)              7
# 욱        WUK      (ㅇ, ㅜ, ㄱ)              7
# 탐        THAM     (ㅌ, ㅏ, ㅁ)              7
# 팽        PHAYNG   (ㅍ, ㅐ, ㅇ)              7
# 갑        KAP      (ㄱ, ㅏ, ㅂ)              7
# 뇨        NYO      (ㄴ, ㅛ, )               7
# 풍        PHWUNG   (ㅍ, ㅜ, ㅇ)              7
# 감        KEM      (ㄱ, ㅏ, ㅁ)              7
# 농        NONG     (ㄴ, ㅗ, ㅇ)              7
# 훤        HWEN     (ㅎ, ㅝ, ㄴ)              7
# 내        NAY      (ㄴ, ㅐ, )               7
# 렬        LYEL     (ㄹ, ㅕ, ㄹ)              7
# 녕        NYENG    (ㄴ, ㅕ, ㅇ)              6
# 림        LIM      (ㄹ, ㅣ, ㅁ)              6
# 붕        PWUNG    (ㅂ, ㅜ, ㅇ)              6
# 윤        YUN      (ㅇ, ㅠ, ㄴ)              6
# 실        SIL      (ㅅ, ㅣ, ㄹ)              6
# 맹        MAYNG    (ㅁ, ㅐ, ㅇ)              6
# 삭        SAK      (ㅅ, ㅏ, ㄱ)              6
# 난        LAN      (ㄴ, ㅏ, ㄴ)              6
# 손        SON      (ㅅ, ㅗ, ㄴ)              6
# 갱        KAYNG    (ㄱ, ㅐ, ㅇ)              6
# 생        SAYNG    (ㅅ, ㅐ, ㅇ)              6
# 길        KIL      (ㄱ, ㅣ, ㄹ)              6
# 엽        YEP      (ㅇ, ㅕ, ㅂ)              6
# 읍        UP       (ㅇ, ㅡ, ㅂ)              6
# 색        SAYK     (ㅅ, ㅐ, ㄱ)              6
# 낙        LAK      (ㄴ, ㅏ, ㄱ)              6
# 난        NAN      (ㄴ, ㅏ, ㄴ)              6
# 욕        YOK      (ㅇ, ㅛ, ㄱ)              6
# 녹        LOK      (ㄴ, ㅗ, ㄱ)              6
# 징        CING     (ㅈ, ㅣ, ㅇ)              6
# 억        EK       (ㅇ, ㅓ, ㄱ)              5
# 월        WEL      (ㅇ, ㅝ, ㄹ)              5
# 옥        OK       (ㅇ, ㅗ, ㄱ)              5
# 힐        HIL      (ㅎ, ㅣ, ㄹ)              5
# 탑        THAP     (ㅌ, ㅏ, ㅂ)              5
# 측        CHUK     (ㅊ, ㅡ, ㄱ)              5
# 흉        HYUNG    (ㅎ, ㅠ, ㅇ)              5
# 걸        KEL      (ㄱ, ㅓ, ㄹ)              5
# 골        KOL      (ㄱ, ㅗ, ㄹ)              5
# 활        HWAL     (ㅎ, ㅘ, ㄹ)              5
# 궐        KWEL     (ㄱ, ㅝ, ㄹ)              5
# 긍        KUNG     (ㄱ, ㅡ, ㅇ)              5
# 혈        HYEL     (ㅎ, ㅕ, ㄹ)              5
# 험        HEM      (ㅎ, ㅓ, ㅁ)              5
# 남        NAM      (ㄴ, ㅏ, ㅁ)              5
# 허        HE       (ㅎ, ㅓ, )               5
# 낭        LANG     (ㄴ, ㅏ, ㅇ)              5
# 행        HAYNG    (ㅎ, ㅐ, ㅇ)              5
# 능        LUNG     (ㄴ, ㅡ, ㅇ)              5
# 토        THO      (ㅌ, ㅗ, )               5
# 촌        CHON     (ㅊ, ㅗ, ㄴ)              5
# 직        CIK      (ㅈ, ㅣ, ㄱ)              5
# 래        LAY      (ㄹ, ㅐ, )               5
# 췌        CHWEY    (ㅊ, ㅞ, )               5
# 잉        ING      (ㅇ, ㅣ, ㅇ)              5
# 률        LYUL     (ㄹ, ㅠ, ㄹ)              5
# 창        CHENG    (ㅊ, ㅏ, ㅇ)              5
# 벌        PEL      (ㅂ, ㅓ, ㄹ)              5
# 잡        CAP      (ㅈ, ㅏ, ㅂ)              5
# 별        PYEL     (ㅂ, ㅕ, ㄹ)              5
# 중        CWUNG    (ㅈ, ㅜ, ㅇ)              5
# 홀        HOL      (ㅎ, ㅗ, ㄹ)              4
# 흠        HUM      (ㅎ, ㅡ, ㅁ)              4
# 응        UNG      (ㅇ, ㅡ, ㅇ)              4
# 족        COK      (ㅈ, ㅗ, ㄱ)              4
# 칙        CHIK     (ㅊ, ㅣ, ㄱ)              4
# 즙        CUP      (ㅈ, ㅡ, ㅂ)              4
# 친        CHIN     (ㅊ, ㅣ, ㄴ)              4
# 헌        HEN      (ㅎ, ㅓ, ㄴ)              4
# 출        CHWUL    (ㅊ, ㅜ, ㄹ)              4
# 핵        HAYK     (ㅎ, ㅐ, ㄱ)              4
# 율        YUL      (ㅇ, ㅠ, ㄹ)              4
# 육        YUK      (ㅇ, ㅠ, ㄱ)              4
# 슬        SUL      (ㅅ, ㅡ, ㄹ)              4
# 남        LAM      (ㄴ, ㅏ, ㅁ)              4
# 살        SAL      (ㅅ, ㅏ, ㄹ)              4
# 답        TAP      (ㄷ, ㅏ, ㅂ)              4
# 숭        SWUNG    (ㅅ, ㅜ, ㅇ)              4
# 술        SWUL     (ㅅ, ㅜ, ㄹ)              4
# 귀        KWI      (ㄱ, ㅟ, )               4
# 쇄        SWAY     (ㅅ, ㅙ, )               4
# 새        SAY      (ㅅ, ㅐ, )               4
# 륙        LYUK     (ㄹ, ㅠ, ㄱ)              4
# 겁        KEP      (ㄱ, ㅓ, ㅂ)              4
# 년        NYEN     (ㄴ, ㅕ, ㄴ)              4
# 념        NYEM     (ㄴ, ㅕ, ㅁ)              4
# 밀        MIL      (ㅁ, ㅣ, ㄹ)              4
# 농        LONG     (ㄴ, ㅗ, ㅇ)              4
# 뇌        LOY      (ㄴ, ㅚ, )               4
# 멸        MYEL     (ㅁ, ㅕ, ㄹ)              4
# 압        AP       (ㅇ, ㅏ, ㅂ)              4
# 맹        MENG     (ㅁ, ㅐ, ㅇ)              4
# 열        YEL      (ㅇ, ㅕ, ㄹ)              4
# 칠        CHIL     (ㅊ, ㅣ, ㄹ)              3
# 쉬        SWI      (ㅅ, ㅟ, )               3
# 할        HAL      (ㅎ, ㅏ, ㄹ)              3
# 존        CON      (ㅈ, ㅗ, ㄴ)              3
# 품        PHWUM    (ㅍ, ㅜ, ㅁ)              3
# 폄        PHYEM    (ㅍ, ㅕ, ㅁ)              3
# 수        SWI      (ㅅ, ㅜ, )               3
# 륭        LYUNG    (ㄹ, ㅠ, ㅇ)              3
# 입        IP       (ㅇ, ㅣ, ㅂ)              3
# 립        LIP      (ㄹ, ㅣ, ㅂ)              3
# 랄        LAL      (ㄹ, ㅏ, ㄹ)              3
# 솔        SOL      (ㅅ, ㅗ, ㄹ)              3
# 폭        PHOK     (ㅍ, ㅗ, ㄱ)              3
# 혹        HOK      (ㅎ, ㅗ, ㄱ)              3
# 췌        CHWI     (ㅊ, ㅞ, )               3
# 략        LYAK     (ㄹ, ㅑ, ㄱ)              3
# 붕        PWUL     (ㅂ, ㅜ, ㅇ)              3
# 룡        LYONG    (ㄹ, ㅛ, ㅇ)              3
# 낭        NANG     (ㄴ, ㅏ, ㅇ)              3
# 납        LAP      (ㄴ, ㅏ, ㅂ)              3
# 삼        CHAM     (ㅅ, ㅏ, ㅁ)              3
# 렵        LYEP     (ㄹ, ㅕ, ㅂ)              3
# 특        THUK     (ㅌ, ㅡ, ㄱ)              3
# 다        TA       (ㄷ, ㅏ, )               3
# 왜        WAY      (ㅇ, ㅙ, )               3
# 졸        COL      (ㅈ, ㅗ, ㄹ)              3
# 눌        NWUL     (ㄴ, ㅜ, ㄹ)              3
# 뉴        NYU      (ㄴ, ㅠ, )               3
# 멱        MYEK     (ㅁ, ㅕ, ㄱ)              3
# 뇌        NOY      (ㄴ, ㅚ, )               3
# 올        OL       (ㅇ, ㅗ, ㄹ)              3
# 게        KEY      (ㄱ, ㅔ, )               3
# 휼        HYUL     (ㅎ, ㅠ, ㄹ)              3
# 팔        PHAL     (ㅍ, ㅏ, ㄹ)              3
# 탈        THAL     (ㅌ, ㅏ, ㄹ)              3
# 핍        PHIP     (ㅍ, ㅣ, ㅂ)              3
# 묵        MWUK     (ㅁ, ㅜ, ㄱ)              3
# 짐        CIM      (ㅈ, ㅣ, ㅁ)              3
# 덕        TEK      (ㄷ, ㅓ, ㄱ)              3
# 물        MWUL     (ㅁ, ㅜ, ㄹ)              3
# 횡        HOYNG    (ㅎ, ㅚ, ㅇ)              3
# 쾌        KHWAY    (ㅋ, ㅙ, )               3
# 획        HOYK     (ㅎ, ㅚ, ㄱ)              3
# 융        YUNG     (ㅇ, ㅠ, ㅇ)              3
# 릉        LUNG     (ㄹ, ㅡ, ㅇ)              2
# 몰        MOL      (ㅁ, ㅗ, ㄹ)              2
# 롱        LYONG    (ㄹ, ㅗ, ㅇ)              2
# 닐        NIL      (ㄴ, ㅣ, ㄹ)              2
# 름        LUM      (ㄹ, ㅡ, ㅁ)              2
# 닉        NIK      (ㄴ, ㅣ, ㄱ)              2
# 법        PEP      (ㅂ, ㅓ, ㅂ)              2
# 톤        THON     (ㅌ, ㅗ, ㄴ)              2
# 납        NAP      (ㄴ, ㅏ, ㅂ)              2
# 죽        CWUK     (ㅈ, ㅜ, ㄱ)              2
# 즐        CUL      (ㅈ, ㅡ, ㄹ)              2
# 배        PEY      (ㅂ, ㅐ, )               2
# 즉        CUK      (ㅈ, ㅡ, ㄱ)              2
# 객        KAYK     (ㄱ, ㅐ, ㄱ)              2
# 에        EY       (ㅇ, ㅔ, )               2
# 선        SEY      (ㅅ, ㅓ, ㄴ)              2
# 날        NAL      (ㄴ, ㅏ, ㄹ)              2
# 탱        THAYNG   (ㅌ, ㅐ, ㅇ)              2
# 업        EP       (ㅇ, ㅓ, ㅂ)              2
# 얼        EL       (ㅇ, ㅓ, ㄹ)              2
# 태        THA      (ㅌ, ㅐ, )               2
# 늑        LUK      (ㄴ, ㅡ, ㄱ)              2
# 울        WUL      (ㅇ, ㅜ, ㄹ)              2
# 웅        WUNG     (ㅇ, ㅜ, ㅇ)              2
# 쌍        SSANG    (ㅆ, ㅏ, ㅇ)              2
# 십        SIP      (ㅅ, ㅣ, ㅂ)              2
# 윤        LYUN     (ㅇ, ㅠ, ㄴ)              2
# 칭        CHING    (ㅊ, ㅣ, ㅇ)              2
# 을        UL       (ㅇ, ㅡ, ㄹ)              2
# 숙        SWU      (ㅅ, ㅜ, ㄱ)              2
# 돌        TOL      (ㄷ, ㅗ, ㄹ)              2
# 택        THAYK    (ㅌ, ㅐ, ㄱ)              2
# 락        LAK      (ㄹ, ㅏ, ㄱ)              2
# 나        NA       (ㄴ, ㅏ, )               2
# 춘        CHWUN    (ㅊ, ㅜ, ㄴ)              2
# 완        WEN      (ㅇ, ㅘ, ㄴ)              2
# 나        NAY      (ㄴ, ㅏ, )               2
# 측        CHI      (ㅊ, ㅡ, ㄱ)              2
# 속        SO       (ㅅ, ㅗ, ㄱ)              2
# 욕        YO       (ㅇ, ㅛ, ㄱ)              2
# 늠        LUM      (ㄴ, ㅡ, ㅁ)              1
# 팔        PHA      (ㅍ, ㅏ, ㄹ)              1
# 판        PHA      (ㅍ, ㅏ, ㄴ)              1
# 포        PHOK     (ㅍ, ㅗ, )               1
# 뉵        NYUK     (ㄴ, ㅠ, ㄱ)              1
# 뇨        YO       (ㄴ, ㅛ, )               1
#          LYO      (ㄴ, ㅛ, )               1
# 풍        LYEY     (ㅍ, ㅜ, ㅇ)              1
# 누        NWU      (ㄴ, ㅜ, )               1
# 퍅        PHYAK    (ㅍ, ㅑ, ㄱ)              1
# 폭        PHO      (ㅍ, ㅗ, ㄱ)              1
# 눈        NWUN     (ㄴ, ㅜ, ㄴ)              1
# 예        WUN      (ㅇ, ㅖ, )               1
# 논        LON      (ㄴ, ㅗ, ㄴ)              1
# 건        KAN      (ㄱ, ㅓ, ㄴ)              1
# 곶        KOC      (ㄱ, ㅗ, ㅈ)              1
# 골        MYEK     (ㄱ, ㅗ, ㄹ)              1
# 획        HWA      (ㅎ, ㅚ, ㄱ)              1
# 골        HWAL     (ㄱ, ㅗ, ㄹ)              1
# 곡        KO       (ㄱ, ㅗ, ㄱ)              1
# 훈        HWI      (ㅎ, ㅜ, ㄴ)              1
# 고        KWA      (ㄱ, ㅗ, )               1
# 훌        HWUL     (ㅎ, ㅜ, ㄹ)              1
# 훙        HWUNG    (ㅎ, ㅜ, ㅇ)              1
# 거        CHA      (ㄱ, ㅓ, )               1
# 괵        KOYK     (ㄱ, ㅚ, ㄱ)              1
# 휼        HUL      (ㅎ, ㅠ, ㄹ)              1
# 흉        HUNG     (ㅎ, ㅠ, ㅇ)              1
# 갹        KYAK     (ㄱ, ㅑ, ㄱ)              1
# 흑        HUK      (ㅎ, ㅡ, ㄱ)              1
# 갱        KYENG    (ㄱ, ㅐ, ㅇ)              1
# 강        KONG     (ㄱ, ㅏ, ㅇ)              1
# 감        HAN      (ㄱ, ㅏ, ㅁ)              1
# 흥        HUNG     (ㅎ, ㅡ, ㅇ)              1
# 간        HAN      (ㄱ, ㅏ, ㄴ)              1
# 관        WAN      (ㄱ, ㅘ, ㄴ)              1
# 국        KWU      (ㄱ, ㅜ, ㄱ)              1
# 녕        YENG     (ㄴ, ㅕ, ㅇ)              1
# 낙        AK       (ㄴ, ㅏ, ㄱ)              1
# 학        HYO      (ㅎ, ㅏ, ㄱ)              1
# 녁        NYEK     (ㄴ, ㅕ, ㄱ)              1
# 합        HYEP     (ㅎ, ㅏ, ㅂ)              1
# 녀        NYE      (ㄴ, ㅕ, )               1
# 항        HAYNG    (ㅎ, ㅏ, ㅇ)              1
# 냉        LAYNG    (ㄴ, ㅐ, ㅇ)              1
# 내        LAY      (ㄴ, ㅐ, )               1
# 헐        HEL      (ㅎ, ㅓ, ㄹ)              1
# 낙        NAK      (ㄴ, ㅏ, ㄱ)              1
# 현        HYENG    (ㅎ, ㅕ, ㄴ)              1
# 귤        KYUL     (ㄱ, ㅠ, ㄹ)              1
# 혐        HYEM     (ㅎ, ㅕ, ㅁ)              1
# 나        LAL      (ㄴ, ㅏ, )               1
# 끽        KKIK     (ㄲ, ㅣ, ㄱ)              1
# 긴        KIN      (ㄱ, ㅣ, ㄴ)              1
# 호        HWU      (ㅎ, ㅗ, )               1
# 혹        HYO      (ㅎ, ㅗ, ㄱ)              1
# 긍        SEN      (ㄱ, ㅡ, ㅇ)              1
# 혼        HUN      (ㅎ, ㅗ, ㄴ)              1
# 금        KIM      (ㄱ, ㅡ, ㅁ)              1
# 틈        CHUM     (ㅌ, ㅡ, ㅁ)              1
# 로        LYO      (ㄹ, ㅗ, )               1
# 퉁        TONG     (ㅌ, ㅜ, ㅇ)              1
# 상        YANG     (ㅅ, ㅏ, ㅇ)              1
# 심        CHIM     (ㅅ, ㅣ, ㅁ)              1
# 신        CIN      (ㅅ, ㅣ, ㄴ)              1
# 은        HUN      (ㅇ, ㅡ, ㄴ)              1
# 시        CEY      (ㅅ, ㅣ, )               1
# 승        SUP      (ㅅ, ㅡ, ㅇ)              1
# 이        CEY      (ㅇ, ㅣ, )               1
#          SEN      (ㅇ, ㅣ, )               1
# 수        YU       (ㅅ, ㅜ, )               1
#          SWUK     (ㅅ, ㅜ, )               1
# 쇠        SOY      (ㅅ, ㅚ, )               1
# 쇄        SWA      (ㅅ, ㅙ, )               1
#          SAY      (ㅅ, ㅙ, )               1
# 손        SO       (ㅅ, ㅗ, ㄴ)              1
# 소        SOY      (ㅅ, ㅗ, )               1
#          CHO      (ㅅ, ㅗ, )               1
# 세        HYEY     (ㅅ, ㅔ, )               1
# 섭        YEP      (ㅅ, ㅓ, ㅂ)              1
# 서        YEY      (ㅅ, ㅓ, )               1
# 전        CWUN     (ㅈ, ㅓ, ㄴ)              1
# 심        SIN      (ㅅ, ㅣ, ㅁ)              1
# 위        I        (ㅇ, ㅟ, )               1
# 씨        SSI      (ㅆ, ㅣ, )               1
# 연        YU       (ㅇ, ㅕ, ㄴ)              1
# 영        HYENG    (ㅇ, ㅕ, ㅇ)              1
# 염        YEN      (ㅇ, ㅕ, ㅁ)              1
# 옹        YONG     (ㅇ, ㅗ, ㅇ)              1
# 열        NYEL     (ㅇ, ㅕ, ㄹ)              1
# 와        WAY      (ㅇ, ㅘ, )               1
# 완        KWAN     (ㅇ, ㅘ, ㄴ)              1
# 열        IN       (ㅇ, ㅕ, ㄹ)              1
# 왈        WAL      (ㅇ, ㅘ, ㄹ)              1
# 왜        WI       (ㅇ, ㅙ, )               1
# 아        UY       (ㅇ, ㅏ, )               1
# 엔        WEN      (ㅇ, ㅔ, ㄴ)              1
# 요        LYO      (ㅇ, ㅛ, )               1
# 우        O        (ㅇ, ㅜ, )               1
# 야        YAK      (ㅇ, ㅑ, )               1
# 암        AN       (ㅇ, ㅏ, ㅁ)              1
# 운        HWUN     (ㅇ, ㅜ, ㄴ)              1
#          WEN      (ㅇ, ㅜ, ㄴ)              1
# 알        AN       (ㅇ, ㅏ, ㄹ)              1
# 생        SENG     (ㅅ, ㅐ, ㅇ)              1
# 정        KWU      (ㅈ, ㅓ, ㅇ)              1
# 능        NUNG     (ㄴ, ㅡ, ㅇ)              1
# 제        CA       (ㅈ, ㅔ, )               1
# 멱        SA       (ㅁ, ㅕ, ㄱ)              1
# 리        I        (ㄹ, ㅣ, )               1
# 륵        LUK      (ㄹ, ㅡ, ㄱ)              1
# 률        SOL      (ㄹ, ㅠ, ㄹ)              1
# 촬        CHWAL    (ㅊ, ㅘ, ㄹ)              1
# 오        WUK      (ㅇ, ㅗ, )               1
# 려        LI       (ㄹ, ㅕ, )               1
# 충        HWEY     (ㅊ, ㅜ, ㅇ)              1
# 랍        LAP      (ㄹ, ㅏ, ㅂ)              1
# 층        CHUNG    (ㅊ, ㅡ, ㅇ)              1
# 득        TUK      (ㄷ, ㅡ, ㄱ)              1
# 독        TO       (ㄷ, ㅗ, ㄱ)              1
# 칩        CHIP     (ㅊ, ㅣ, ㅂ)              1
# 도        CO       (ㄷ, ㅗ, )               1
# 댁        TAYK     (ㄷ, ㅐ, ㄱ)              1
# 대        THAY     (ㄷ, ㅐ, )               1
# 담        YEM      (ㄷ, ㅏ, ㅁ)              1
# 다        TAN      (ㄷ, ㅏ, )               1
# 터        THE      (ㅌ, ㅓ, )               1
# 몌        MYEY     (ㅁ, ㅖ, )               1
# 채        CHAYK    (ㅊ, ㅐ, )               1
# 묘        MWU      (ㅁ, ㅛ, )               1
# 즉        CUL      (ㅈ, ㅡ, ㄱ)              1
# 산        SEN      (ㅅ, ㅏ, ㄴ)              1
#          SAM      (ㅅ, ㅏ, ㄴ)              1
# 삭        SWU      (ㅅ, ㅏ, ㄱ)              1
#          SAYK     (ㅅ, ㅏ, ㄱ)              1
# 죄        COY      (ㅈ, ㅚ, )               1
# 빈        YUN      (ㅂ, ㅣ, ㄴ)              1
# 비        PHIL     (ㅂ, ㅣ, )               1
# 줄        CWUL     (ㅈ, ㅜ, ㄹ)              1
# 즙        CIP      (ㅈ, ㅡ, ㅂ)              1
# 박        POK      (ㅂ, ㅏ, ㄱ)              1
# 본        PON      (ㅂ, ㅗ, ㄴ)              1
# 보        PWU      (ㅂ, ㅗ, )               1
# 변        PHYEN    (ㅂ, ㅕ, ㄴ)              1
# 벽        PHI      (ㅂ, ㅕ, ㄱ)              1
# 백        PEYK     (ㅂ, ㅐ, ㄱ)              1
# 배        PWUK     (ㅂ, ㅐ, )               1
#          PHAY     (ㅂ, ㅐ, )               1
# 반        PIN      (ㅂ, ㅏ, ㄴ)              1
# 가        HA       (ㄱ, ㅏ, )               1
# Name: count, dtype: int64

# %%
import re
import unicodedata

# Pinyin initials (including digraphs)
INITIALS = [
    "zh", "ch", "sh",  # must come before "z", "c", "s"
    "b", "p", "m", "f", "d", "t", "n", "l",
    "g", "k", "h", "j", "q", "x",
    "r", "z", "c", "s", "y", "w"
]

# Vowel mapping with tones
PINYIN_TONE_MAP = {
    "ā": ("a", 1), "á": ("a", 2), "ǎ": ("a", 3), "à": ("a", 4),
    "ē": ("e", 1), "é": ("e", 2), "ě": ("e", 3), "è": ("e", 4),
    "ī": ("i", 1), "í": ("i", 2), "ǐ": ("i", 3), "ì": ("i", 4),
    "ō": ("o", 1), "ó": ("o", 2), "ǒ": ("o", 3), "ò": ("o", 4),
    "ū": ("u", 1), "ú": ("u", 2), "ǔ": ("u", 3), "ù": ("u", 4),
    "ǖ": ("ü", 1), "ǘ": ("ü", 2), "ǚ": ("ü", 3), "ǜ": ("ü", 4),
    # plain vowels (neutral tone)
    "a": ("a", 5), "e": ("e", 5), "i": ("i", 5), "o": ("o", 5),
    "u": ("u", 5), "ü": ("ü", 5),
}

def split_pinyin(pinyin):
    # Step 1: find and normalize tone-marked vowel
    tone = 5
    final_chars = []
    for ch in pinyin:
        if ch in PINYIN_TONE_MAP:
            base, tone = PINYIN_TONE_MAP[ch]
            final_chars.append(base)
        else:
            final_chars.append(ch)
    pinyin_norm = ''.join(final_chars)

    # Step 2: match initial from the start
    initial = ''
    for init in INITIALS:
        if pinyin_norm.startswith(init):
            initial = init
            break
    final = pinyin_norm[len(initial):]

    return initial, final, tone

df["decomposed_pinyin"]     = df.kMandarin.apply(split_pinyin)
df["toneless_pinyin"] = df.decomposed_pinyin.apply(lambda t: t[0] + t[1].replace("ü", "v"))

df[["kMandarin", "decomposed_pinyin", "toneless_pinyin"]].value_counts()
# Out:
# kMandarin  decomposed_pinyin  toneless_pinyin
# yì         (y, i, 4)          yi                 60
# xī         (x, i, 1)          xi                 50
# bì         (b, i, 4)          bi                 49
# zhì        (zh, i, 4)         zhi                44
# yù         (y, u, 4)          yu                 43
# fú         (f, u, 2)          fu                 41
# lì         (l, i, 4)          li                 40
# shì        (sh, i, 4)         shi                40
# jī         (j, i, 1)          ji                 39
# yú         (y, u, 2)          yu                 38
# qí         (q, i, 2)          qi                 35
# jì         (j, i, 4)          ji                 31
# jí         (j, i, 2)          ji                 29
# yàn        (y, an, 4)         yan                27
# huì        (h, ui, 4)         hui                27
# jiàn       (j, ian, 4)        jian               26
# fù         (f, u, 4)          fu                 26
# xiè        (x, ie, 4)         xie                25
# jué        (j, ue, 2)         jue                25
# wěi        (w, ei, 5)         wei                24
# jié        (j, ie, 2)         jie                24
# líng       (l, ing, 2)        ling               24
# jù         (j, u, 4)          ju                 24
# jiān       (j, ian, 1)        jian               23
# è          (, e, 4)           e                  23
# yuán       (y, uan, 2)        yuan               23
# hé         (h, e, 2)          he                 22
# jìn        (j, in, 4)         jin                22
# lù         (l, u, 4)          lu                 22
# xù         (x, u, 4)          xu                 21
# sù         (s, u, 4)          su                 21
# bó         (b, o, 2)          bo                 21
# zhī        (zh, i, 1)         zhi                20
# jiǎn       (j, ian, 3)        jian               20
# shū        (sh, u, 1)         shu                20
# hú         (h, u, 2)          hu                 20
# yán        (y, an, 2)         yan                20
# zī         (z, i, 1)          zi                 19
# chéng      (ch, eng, 2)       cheng              19
# qī         (q, i, 1)          qi                 19
# yǔ         (y, u, 3)          yu                 19
# yǎn        (y, an, 3)         yan                19
# yí         (y, i, 2)          yi                 19
# lín        (l, in, 2)         lin                19
# lí         (l, i, 2)          li                 19
# jiā        (j, ia, 1)         jia                18
# jiāo       (j, iao, 5)        jiao               18
# chán       (ch, an, 2)        chan               18
# xiàn       (x, ian, 4)        xian               18
# zhù        (zh, u, 4)         zhu                18
# jìng       (j, ing, 4)        jing               18
# gǔ         (g, u, 3)          gu                 18
# qì         (q, i, 4)          qi                 17
# wèi        (w, ei, 5)         wei                17
# yīng       (y, ing, 1)        ying               17
# qū         (q, u, 1)          qu                 17
# sì         (s, i, 4)          si                 17
# píng       (p, ing, 2)        ping               17
# xiāo       (x, iao, 5)        xiao               17
# huáng      (h, uang, 2)       huang              17
# hàn        (h, an, 4)         han                17
# yīn        (y, in, 1)         yin                17
# zhēn       (zh, en, 1)        zhen               16
# jīng       (j, ing, 1)        jing               16
# mò         (m, o, 4)          mo                 16
# zhū        (zh, u, 1)         zhu                16
# qiú        (q, iu, 2)         qiu                16
# xū         (x, u, 1)          xu                 16
# jū         (j, u, 1)          ju                 16
# bèi        (b, ei, 5)         bei                16
# fǔ         (f, u, 3)          fu                 16
# xì         (x, i, 4)          xi                 16
# shù        (sh, u, 4)         shu                16
# zhǐ        (zh, i, 3)         zhi                16
# qiān       (q, ian, 1)        qian               16
# yíng       (y, ing, 2)        ying               16
# méi        (m, ei, 5)         mei                16
# quán       (q, uan, 2)        quan               15
# lǐ         (l, i, 3)          li                 15
# dié        (d, ie, 2)         die                15
# tuó        (t, uo, 2)         tuo                15
# shàn       (sh, an, 4)        shan               15
# yín        (y, in, 2)         yin                15
# yè         (y, e, 4)          ye                 15
# róng       (r, ong, 2)        rong               15
# dài        (d, ai, 5)         dai                15
# lú         (l, u, 2)          lu                 15
# liáo       (l, iao, 5)        liao               15
# yún        (y, un, 2)         yun                15
# yáo        (y, ao, 5)         yao                15
# xián       (x, ian, 2)        xian               15
# biàn       (b, ian, 4)        bian               15
# chóu       (ch, ou, 5)        chou               15
# xún        (x, un, 2)         xun                15
# wǔ         (w, u, 3)          wu                 15
# xié        (x, ie, 2)         xie                15
# yī         (y, i, 1)          yi                 15
# jǐn        (j, in, 3)         jin                15
# jùn        (j, un, 4)         jun                15
# jiāng      (j, iang, 1)       jiang              14
# xiǎn       (x, ian, 3)        xian               14
# qián       (q, ian, 2)        qian               14
# xiá        (x, ia, 2)         xia                14
# lóng       (l, ong, 2)        long               14
# wǎn        (w, an, 3)         wan                14
# gōng       (g, ong, 1)        gong               14
# shí        (sh, i, 2)         shi                14
# zhān       (zh, an, 1)        zhan               14
# dàn        (d, an, 4)         dan                14
# yǒng       (y, ong, 3)        yong               14
# yuè        (y, ue, 4)         yue                14
# jiǎo       (j, iao, 5)        jiao               14
# shēn       (sh, en, 1)        shen               14
# zhí        (zh, i, 2)         zhi                14
# kē         (k, e, 1)          ke                 14
# yōng       (y, ong, 1)        yong               14
# mí         (m, i, 2)          mi                 14
# mì         (m, i, 4)          mi                 14
# què        (q, ue, 4)         que                14
# méng       (m, eng, 2)        meng               14
# xuān       (x, uan, 1)        xuan               14
# pí         (p, i, 2)          pi                 14
# yùn        (y, un, 4)         yun                13
# hào        (h, ao, 5)         hao                13
# diàn       (d, ian, 4)        dian               13
# huī        (h, ui, 1)         hui                13
# cuì        (c, ui, 4)         cui                13
# lán        (l, an, 2)         lan                13
# jiù        (j, iu, 4)         jiu                13
# wù         (w, u, 4)          wu                 13
# huàn       (h, uan, 4)        huan               13
# yáng       (y, ang, 2)        yang               13
# chī        (ch, i, 1)         chi                13
# xīn        (x, in, 1)         xin                13
# yòu        (y, ou, 5)         you                13
# yóu        (y, ou, 5)         you                13
# xūn        (x, un, 1)         xun                13
# xiān       (x, ian, 1)        xian               13
# hù         (h, u, 4)          hu                 13
# mào        (m, ao, 5)         mao                13
# tóng       (t, ong, 2)        tong               13
# shān       (sh, an, 1)        shan               13
# huán       (h, uan, 2)        huan               12
# wéi        (w, ei, 5)         wei                12
# zhuó       (zh, uo, 2)        zhuo               12
# zhēng      (zh, eng, 1)       zheng              12
# lián       (l, ian, 2)        lian               12
# qiàn       (q, ian, 4)        qian               12
# shī        (sh, i, 1)         shi                12
# guàn       (g, uan, 4)        guan               12
# bù         (b, u, 4)          bu                 12
# xuàn       (x, uan, 4)        xuan               12
# dì         (d, i, 4)          di                 12
# guī        (g, ui, 1)         gui                12
# gū         (g, u, 1)          gu                 12
# fēng       (f, eng, 1)        feng               12
# liú        (l, iu, 2)         liu                12
# sī         (s, i, 1)          si                 12
# jiào       (j, iao, 5)        jiao               12
# qiū        (q, iu, 1)         qiu                12
# péng       (p, eng, 2)        peng               12
# zhāng      (zh, ang, 1)       zhang              12
# hóng       (h, ong, 2)        hong               12
# é          (, e, 2)           e                  12
# wú         (w, u, 2)          wu                 12
# tái        (t, ai, 5)         tai                12
# yān        (y, an, 1)         yan                12
# tán        (t, an, 2)         tan                12
# mù         (m, u, 4)          mu                 12
# qú         (q, u, 2)          qu                 11
# dān        (d, an, 1)         dan                11
# xiāng      (x, iang, 1)       xiang              11
# liè        (l, ie, 4)         lie                11
# shā        (sh, a, 1)         sha                11
# huò        (h, uo, 4)         huo                11
# qiāng      (q, iang, 1)       qiang              11
# xiào       (x, iao, 5)        xiao               11
# yǐ         (y, i, 3)          yi                 11
# gé         (g, e, 2)          ge                 11
# áo         (, ao, 5)          ao                 11
# jīn        (j, in, 1)         jin                11
# zhòu       (zh, ou, 5)        zhou               11
# fén        (f, en, 2)         fen                11
# dí         (d, i, 2)          di                 11
# suì        (s, ui, 4)         sui                11
# pī         (p, i, 1)          pi                 11
# míng       (m, ing, 2)        ming               11
# bǐ         (b, i, 3)          bi                 11
# tì         (t, i, 4)          ti                 11
# liàn       (l, ian, 4)        lian               11
# bīn        (b, in, 1)         bin                11
# jiē        (j, ie, 1)         jie                11
# shè        (sh, e, 4)         she                11
# gòu        (g, ou, 5)         gou                11
# kūn        (k, un, 1)         kun                11
# rèn        (r, en, 4)         ren                11
# táng       (t, ang, 2)        tang               11
# qǐ         (q, i, 3)          qi                 10
# wò         (w, o, 4)          wo                 10
# jǐng       (j, ing, 3)        jing               10
# láng       (l, ang, 2)        lang               10
# jiè        (j, ie, 4)         jie                10
# biāo       (b, iao, 5)        biao               10
# chén       (ch, en, 2)        chen               10
# jǔ         (j, u, 3)          ju                 10
# chì        (ch, i, 4)         chi                10
# niè        (n, ie, 4)         nie                10
# zhé        (zh, e, 2)         zhe                10
# dǐ         (d, i, 3)          di                 10
# xǐ         (x, i, 3)          xi                 10
# qín        (q, in, 2)         qin                10
# bǐng       (b, ing, 3)        bing               10
# jiǎ        (j, ia, 3)         jia                10
# mǐn        (m, in, 3)         min                10
# qiè        (q, ie, 4)         qie                10
# ài         (, ai, 5)          ai                 10
# jiǒng      (j, iong, 3)       jiong              10
# ào         (, ao, 5)          ao                 10
# wēi        (w, ei, 5)         wei                10
# tí         (t, i, 2)          ti                 10
# xùn        (x, un, 4)         xun                10
# shòu       (sh, ou, 5)        shou               10
# cí         (c, i, 2)          ci                 10
# gāo        (g, ao, 5)         gao                10
# yōu        (y, ou, 5)         you                10
# gāng       (g, ang, 1)        gang               10
# chú        (ch, u, 2)         chu                10
# zhào       (zh, ao, 5)        zhao               10
# zhōu       (zh, ou, 5)        zhou                9
# gē         (g, e, 1)          ge                  9
# shǔ        (sh, u, 3)         shu                 9
# zuò        (z, uo, 4)         zuo                 9
# liáng      (l, iang, 2)       liang               9
# kuí        (k, ui, 2)         kui                 9
# juàn       (j, uan, 4)        juan                9
# jǐ         (j, i, 3)          ji                  9
# shēng      (sh, eng, 1)       sheng               9
# kuì        (k, ui, 4)         kui                 9
# gān        (g, an, 1)         gan                 9
# zì         (z, i, 4)          zi                  9
# qīng       (q, ing, 1)        qing                9
# mó         (m, o, 2)          mo                  9
# yuàn       (y, uan, 4)        yuan                9
# zǐ         (z, i, 3)          zi                  9
# bān        (b, an, 1)         ban                 9
# táo        (t, ao, 5)         tao                 9
# xíng       (x, ing, 2)        xing                9
# dú         (d, u, 2)          du                  9
# ní         (n, i, 2)          ni                  9
# fàn        (f, an, 4)         fan                 9
# zhàng      (zh, ang, 4)       zhang               9
# fán        (f, an, 2)         fan                 9
# xiū        (x, iu, 1)         xiu                 9
# fèi        (f, ei, 5)         fei                 9
# zhōng      (zh, ong, 1)       zhong               9
# chí        (ch, i, 2)         chi                 9
# lǚ         (l, ü, 3)          lv                  9
# chōng      (ch, ong, 1)       chong               9
# dòng       (d, ong, 4)        dong                9
# fū         (f, u, 1)          fu                  9
# yá         (y, a, 2)          ya                  9
# diāo       (d, iao, 5)        diao                9
# àn         (, an, 4)          an                  9
# tāo        (t, ao, 5)         tao                 9
# cè         (c, e, 4)          ce                  9
# fēi        (f, ei, 5)         fei                 9
# pì         (p, i, 4)          pi                  8
# pú         (p, u, 2)          pu                  8
# qióng      (q, iong, 2)       qiong               8
# zhèn       (zh, en, 4)        zhen                8
# shèn       (sh, en, 4)        shen                8
# lǔ         (l, u, 3)          lu                  8
# kǎi        (k, ai, 5)         kai                 8
# jiū        (j, iu, 1)         jiu                 8
# zhèng      (zh, eng, 4)       zheng               8
# bǎo        (b, ao, 5)         bao                 8
# zhà        (zh, a, 4)         zha                 8
# tíng       (t, ing, 2)        ting                8
# xiàng      (x, iang, 4)       xiang               8
# cōng       (c, ong, 1)        cong                8
# chǎn       (ch, an, 3)        chan                8
# máo        (m, ao, 5)         mao                 8
# máng       (m, ang, 2)        mang                8
# màn        (m, an, 4)         man                 8
# yāo        (y, ao, 5)         yao                 8
# miǎn       (m, ian, 3)        mian                8
# mín        (m, in, 2)         min                 8
# tú         (t, u, 2)          tu                  8
# chún       (ch, un, 2)        chun                8
# cháng      (ch, ang, 2)       chang               8
# wū         (w, u, 1)          wu                  8
# jiǔ        (j, iu, 3)         jiu                 8
# téng       (t, eng, 2)        teng                8
# chuí       (ch, ui, 2)        chui                8
# wǎng       (w, ang, 3)        wang                8
# bō         (b, o, 1)          bo                  8
# zào        (z, ao, 5)         zao                 8
# huà        (h, ua, 4)         hua                 8
# qiáng      (q, iang, 2)       qiang               8
# gù         (g, u, 4)          gu                  8
# xiōng      (x, iong, 1)       xiong               8
# ruì        (r, ui, 4)         rui                 8
# dào        (d, ao, 5)         dao                 8
# nì         (n, i, 4)          ni                  8
# bào        (b, ao, 5)         bao                 8
# guǐ        (g, ui, 3)         gui                 8
# bàng       (b, ang, 4)        bang                8
# luán       (l, uan, 2)        luan                8
# xuán       (x, uan, 2)        xuan                8
# xìng       (x, ing, 4)        xing                8
# fān        (f, an, 1)         fan                 8
# kuàng      (k, uang, 4)       kuang               8
# kuò        (k, uo, 4)         kuo                 8
# xí         (x, i, 2)          xi                  8
# dǎo        (d, ao, 5)         dao                 8
# yào        (y, ao, 5)         yao                 8
# bā         (b, a, 1)          ba                  8
# dùn        (d, un, 4)         dun                 8
# zhěn       (zh, en, 3)        zhen                8
# lóu        (l, ou, 5)         lou                 8
# dòu        (d, ou, 5)         dou                 8
# qiáo       (q, iao, 5)        qiao                8
# juān       (j, uan, 1)        juan                8
# dù         (d, u, 4)          du                  8
# xiù        (x, iu, 4)         xiu                 8
# tián       (t, ian, 2)        tian                8
# níng       (n, ing, 2)        ning                8
# dī         (d, i, 1)          di                  8
# pàn        (p, an, 4)         pan                 7
# kān        (k, an, 1)         kan                 7
# chǎng      (ch, ang, 3)       chang               7
# biān       (b, ian, 1)        bian                7
# nóng       (n, ong, 2)        nong                7
# qíng       (q, ing, 2)        qing                7
# kuī        (k, ui, 1)         kui                 7
# kè         (k, e, 4)          ke                  7
# wán        (w, an, 2)         wan                 7
# chēng      (ch, eng, 1)       cheng               7
# bàn        (b, an, 4)         ban                 7
# wén        (w, en, 2)         wen                 7
# zàn        (z, an, 4)         zan                 7
# zhàn       (zh, an, 4)        zhan                7
# ān         (, an, 1)          an                  7
# bēi        (b, ei, 5)         bei                 7
# fǎng       (f, ang, 3)        fang                7
# pèi        (p, ei, 5)         pei                 7
# chǐ        (ch, i, 3)         chi                 7
# yà         (y, a, 4)          ya                  7
# huí        (h, ui, 2)         hui                 7
# pín        (p, in, 2)         pin                 7
# lǎn        (l, an, 3)         lan                 7
# dá         (d, a, 2)          da                  7
# dèng       (d, eng, 4)        deng                7
# tiáo       (t, iao, 5)        tiao                7
# yuān       (y, uan, 1)        yuan                7
# yǐn        (y, in, 3)         yin                 7
# lún        (l, un, 2)         lun                 7
# zǎo        (z, ao, 5)         zao                 7
# qiào       (q, iao, 5)        qiao                7
# kǎn        (k, an, 3)         kan                 7
# zhǎn       (zh, an, 3)        zhan                7
# léi        (l, ei, 5)         lei                 7
# pǔ         (p, u, 3)          pu                  7
# pǐ         (p, i, 3)          pi                  7
# shǐ        (sh, i, 3)         shi                 7
# luó        (l, uo, 2)         luo                 7
# sè         (s, e, 4)          se                  7
# là         (l, a, 4)          la                  7
# fěi        (f, ei, 5)         fei                 7
# zūn        (z, un, 1)         zun                 7
# tà         (t, a, 4)          ta                  7
# gǒu        (g, ou, 5)         gou                 7
# zhǔ        (zh, u, 3)         zhu                 7
# pán        (p, an, 2)         pan                 7
# qiāo       (q, iao, 5)        qiao                7
# hòu        (h, ou, 5)         hou                 7
# hè         (h, e, 4)          he                  7
# miǎo       (m, iao, 5)        miao                7
# zhú        (zh, u, 2)         zhu                 7
# hán        (h, an, 2)         han                 7
# mèi        (m, ei, 5)         mei                 7
# cù         (c, u, 4)          cu                  7
# zé         (z, e, 2)          ze                  7
# chǔ        (ch, u, 3)         chu                 7
# lǜ         (l, ü, 4)          lv                  7
# héng       (h, eng, 2)        heng                7
# zhuī       (zh, ui, 1)        zhui                6
# náo        (n, ao, 5)         nao                 6
# mán        (m, an, 2)         man                 6
# zhuāng     (zh, uang, 1)      zhuang              6
# luò        (l, uo, 4)         luo                 6
# yǒu        (y, ou, 5)         you                 6
# lài        (l, ai, 5)         lai                 6
# lìn        (l, in, 4)         lin                 6
# lèi        (l, ei, 5)         lei                 6
# kū         (k, u, 1)          ku                  6
# páo        (p, ao, 5)         pao                 6
# qīn        (q, in, 1)         qin                 6
# qìng       (q, ing, 4)        qing                6
# lái        (l, ai, 5)         lai                 6
# móu        (m, ou, 5)         mou                 6
# zhuān      (zh, uan, 1)       zhuan               6
# liàng      (l, iang, 4)       liang               6
# zhuàn      (zh, uan, 4)       zhuan               6
# kāng       (k, ang, 1)        kang                6
# lěi        (l, ei, 5)         lei                 6
# zhuì       (zh, ui, 4)        zhui                6
# zhǒng      (zh, ong, 3)       zhong               6
# nán        (n, an, 2)         nan                 6
# kuài       (k, uai, 5)        kuai                6
# tǐng       (t, ing, 3)        ting                6
# wēn        (w, en, 1)         wen                 6
# suō        (s, uo, 1)         suo                 6
# huá        (h, ua, 2)         hua                 6
# fá         (f, a, 2)          fa                  6
# wā         (w, a, 1)          wa                  6
# āi         (, ai, 5)          ai                  6
# gǎo        (g, ao, 5)         gao                 6
# chù        (ch, u, 4)         chu                 6
# gōu        (g, ou, 5)         gou                 6
# chāng      (ch, ang, 1)       chang               6
# chāo       (ch, ao, 5)        chao                6
# cì         (c, i, 4)          ci                  6
# shāo       (sh, ao, 5)        shao                6
# cāng       (c, ang, 1)        cang                6
# yìn        (y, in, 4)         yin                 6
# shěn       (sh, en, 3)        shen                6
# gàn        (g, an, 4)         gan                 6
# cuò        (c, uo, 4)         cuo                 6
# cuī        (c, ui, 1)         cui                 6
# guǒ        (g, uo, 3)         guo                 6
# guǎn       (g, uan, 3)        guan                6
# fēn        (f, en, 1)         fen                 6
# guāng      (g, uang, 1)       guang               6
# guān       (g, uan, 1)        guan                6
# zōng       (z, ong, 1)        zong                6
# guì        (g, ui, 4)         gui                 6
# huǎng      (h, uang, 3)       huang               6
# guà        (g, ua, 4)         gua                 6
# shà        (sh, a, 4)         sha                 6
# bà         (b, a, 4)          ba                  6
# ōu         (, ou, 5)          ou                  6
# jià        (j, ia, 4)         jia                 6
# dīng       (d, ing, 1)        ding                6
# bìng       (b, ing, 4)        bing                6
# yāng       (y, ang, 1)        yang                6
# wō         (w, o, 1)          wo                  6
# biǎn       (b, ian, 3)        bian                6
# ěr         (, er, 3)          er                  6
# sōng       (s, ong, 1)        song                6
# hōng       (h, ong, 1)        hong                6
# róu        (r, ou, 5)         rou                 6
# rú         (r, u, 2)          ru                  6
# tuō        (t, uo, 1)         tuo                 6
# jūn        (j, un, 1)         jun                 6
# yā         (y, a, 1)          ya                  6
# cǎi        (c, ai, 5)         cai                 6
# shuò       (sh, uo, 4)        shuo                6
# ruò        (r, uo, 4)         ruo                 6
# chuò       (ch, uo, 4)        chuo                6
# duì        (d, ui, 4)         dui                 6
# duō        (d, uo, 1)         duo                 5
# zhā        (zh, a, 1)         zha                 5
# cán        (c, an, 2)         can                 5
# pò         (p, o, 4)          po                  5
# diǎn       (d, ian, 3)        dian                5
# cáo        (c, ao, 5)         cao                 5
# duàn       (d, uan, 4)        duan                5
# páng       (p, ang, 2)        pang                5
# cóng       (c, ong, 2)        cong                5
# diào       (d, iao, 5)        diao                5
# péi        (p, ei, 5)         pei                 5
# ái         (, ai, 5)          ai                  5
# cān        (c, an, 1)         can                 5
# chēn       (ch, en, 1)        chen                5
# cái        (c, ai, 5)         cai                 5
# bǎn        (b, an, 3)         ban                 5
# nài        (n, ai, 5)         nai                 5
# nà         (n, a, 4)          na                  5
# niǎo       (n, iao, 5)        niao                5
# xiǎng      (x, iang, 3)       xiang               5
# bìn        (b, in, 4)         bin                 5
# bāng       (b, ang, 1)        bang                5
# xiē        (x, ie, 1)         xie                 5
# mǔ         (m, u, 3)          mu                  5
# zhè        (zh, e, 4)         zhe                 5
# bǎi        (b, ai, 5)         bai                 5
# zhuàng     (zh, uang, 4)      zhuang              5
# mài        (m, ai, 5)         mai                 5
# chàng      (ch, ang, 4)       chang               5
# měi        (m, ei, 5)         mei                 5
# cháo       (ch, ao, 5)        chao                5
# chèn       (ch, en, 4)        chen                5
# chān       (ch, an, 1)        chan                5
# dàng       (d, ang, 4)        dang                5
# xīng       (x, ing, 1)        xing                5
# tǎn        (t, an, 3)         tan                 5
# tīng       (t, ing, 1)        ting                5
# tān        (t, an, 1)         tan                 5
# zǔ         (z, u, 3)          zu                  5
# dāng       (d, ang, 1)        dang                5
# dìng       (d, ing, 4)        ding                5
# guō        (g, uo, 1)         guo                 5
# yū         (y, u, 1)          yu                  5
# gài        (g, ai, 5)         gai                 5
# zāi        (z, ai, 5)         zai                 5
# gēng       (g, eng, 1)        geng                5
# yǐng       (y, ing, 3)        ying                5
# gěng       (g, eng, 3)        geng                5
# gǎn        (g, an, 3)         gan                 5
# gǒng       (g, ong, 3)        gong                5
# kǔn        (k, un, 3)         kun                 5
# huái       (h, uai, 5)        huai                5
# shào       (sh, ao, 5)        shao                5
# huǐ        (h, ui, 3)         hui                 5
# háo        (h, ao, 5)         hao                 5
# hóu        (h, ou, 5)         hou                 5
# zuì        (z, ui, 4)         zui                 5
# rù         (r, u, 4)          ru                  5
# qiǎn       (q, ian, 3)        qian                5
# hū         (h, u, 1)          hu                  5
# hūn        (h, un, 1)         hun                 5
# kòu        (k, ou, 5)         kou                 5
# jiàng      (j, iang, 4)       jiang               5
# jiá        (j, ia, 2)         jia                 5
# kàn        (k, an, 4)         kan                 5
# jiōng      (j, iong, 1)       jiong               5
# qù         (q, u, 4)          qu                  5
# zēng       (z, eng, 1)        zeng                5
# shú        (sh, u, 2)         shu                 5
# fèn        (f, en, 4)         fen                 5
# yǎo        (y, ao, 5)         yao                 5
# yàng       (y, ang, 4)        yang                5
# yǎng       (y, ang, 3)        yang                5
# sòng       (s, ong, 4)        song                5
# sū         (s, u, 1)          su                  5
# dōng       (d, ong, 1)        dong                5
# pēng       (p, eng, 1)        peng                5
# fáng       (f, ang, 2)        fang                5
# sōu        (s, ou, 5)         sou                 5
# dǔ         (d, u, 3)          du                  5
# dūn        (d, un, 1)         dun                 5
# sǒu        (s, ou, 5)         sou                 5
# dǎn        (d, an, 3)         dan                 5
# xiā        (x, ia, 1)         xia                 4
# sǒng       (s, ong, 3)        song                4
# tài        (t, ai, 5)         tai                 4
# xiáng      (x, iang, 2)       xiang               4
# pū         (p, u, 1)          pu                  4
# nú         (n, u, 2)          nu                  4
# yē         (y, e, 1)          ye                  4
# ráo        (r, ao, 5)         rao                 4
# pù         (p, u, 4)          pu                  4
# tuò        (t, uo, 4)         tuo                 4
# xiǎo       (x, iao, 5)        xiao                4
# ráng       (r, ang, 2)        rang                4
# tuì        (t, ui, 4)         tui                 4
# xué        (x, ue, 2)         xue                 4
# zhuō       (zh, uo, 1)        zhuo                4
# yě         (y, e, 3)          ye                  4
# tiǎn       (t, ian, 3)        tian                4
# xià        (x, ia, 4)         xia                 4
# sāo        (s, ao, 5)         sao                 4
# tàn        (t, an, 4)         tan                 4
# nǎi        (n, ai, 5)         nai                 4
# pái        (p, ai, 5)         pai                 4
# tūn        (t, un, 1)         tun                 4
# yūn        (y, un, 1)         yun                 4
# suǒ        (s, uo, 3)         suo                 4
# sà         (s, a, 4)          sa                  4
# tǐ         (t, i, 3)          ti                  4
# pào        (p, ao, 5)         pao                 4
# tún        (t, un, 2)         tun                 4
# shāng      (sh, ang, 1)       shang               4
# wàn        (w, an, 4)         wan                 4
# wàng       (w, ang, 4)        wang                4
# shùn       (sh, un, 4)        shun                4
# yìng       (y, ing, 4)        ying                4
# shèng      (sh, eng, 4)       sheng               4
# yǔn        (y, un, 3)         yun                 4
# wān        (w, an, 1)         wan                 4
# piào       (p, iao, 5)        piao                4
# sháo       (sh, ao, 5)        shao                4
# pō         (p, o, 1)          po                  4
# wěn        (w, en, 3)         wen                 4
# shuāng     (sh, uang, 1)      shuang              4
# ǒu         (, ou, 5)          ou                  4
# láo        (l, ao, 5)         lao                 4
# zāng       (z, ang, 1)        zang                4
# zhāo       (zh, ao, 5)        zhao                4
# zài        (z, ai, 5)         zai                 4
# zú         (z, u, 2)          zu                  4
# chǒu       (ch, ou, 5)        chou                4
# cuàn       (c, uan, 4)        cuan                4
# cuō        (c, uo, 1)         cuo                 4
# miè        (m, ie, 4)         mie                 4
# mián       (m, ian, 2)        mian                4
# kàng       (k, ang, 4)        kang                4
# càn        (c, an, 4)         can                 4
# miàn       (m, ian, 4)        mian                4
# lǒng       (l, ong, 3)        long                4
# còu        (c, ou, 5)         cou                 4
# guǎng      (g, uang, 3)       guang               4
# cūn        (c, un, 1)         cun                 4
# kù         (k, u, 4)          ku                  4
# chā        (ch, a, 1)         cha                 4
# zhěng      (zh, eng, 3)       zheng               4
# diān       (d, ian, 1)        dian                4
# guā        (g, ua, 1)         gua                 4
# lòu        (l, ou, 5)         lou                 4
# zōu        (z, ou, 5)         zou                 4
# dé         (d, e, 2)          de                  4
# fāng       (f, ang, 1)        fang                4
# luǒ        (l, uo, 3)         luo                 4
# zhūn       (zh, un, 1)        zhun                4
# kěn        (k, en, 3)         ken                 4
# kōng       (k, ong, 1)        kong                4
# zhǔn       (zh, un, 3)        zhun                4
# kǎo        (k, ao, 5)         kao                 4
# fèng       (f, eng, 4)        feng                4
# ér         (, er, 2)          er                  4
# dǒu        (d, ou, 5)         dou                 4
# kuāng      (k, uang, 1)       kuang               4
# chuàng     (ch, uang, 4)      chuang              4
# jú         (j, u, 2)          ju                  4
# mǐ         (m, i, 3)          mi                  4
# nián       (n, ian, 2)        nian                4
# chè        (ch, e, 4)         che                 4
# hái        (h, ai, 5)         hai                 4
# mǎ         (m, a, 3)          ma                  4
# zhòng      (zh, ong, 4)       zhong               4
# ǎi         (, ai, 5)          ai                  4
# bāo        (b, ao, 5)         bao                 4
# niǎn       (n, ian, 3)        nian                4
# hún        (h, un, 2)         hun                 4
# chuán      (ch, uan, 2)       chuan               4
# chà        (ch, a, 4)         cha                 4
# gǔn        (g, un, 3)         gun                 4
# hān        (h, an, 1)         han                 4
# chá        (ch, a, 2)         cha                 4
# huàng      (h, uang, 4)       huang               4
# chuāng     (ch, uang, 1)      chuang              4
# rěn        (r, en, 3)         ren                 3
# fǎn        (f, an, 3)         fan                 3
# rǔ         (r, u, 3)          ru                  3
# féi        (f, ei, 5)         fei                 3
# féng       (f, eng, 2)        feng                3
# guài       (g, uai, 5)        guai                3
# hùn        (h, un, 4)         hun                 3
# rǎn        (r, an, 3)         ran                 3
# suī        (s, ui, 1)         sui                 3
# shuì       (sh, ui, 4)        shui                3
# háng       (h, ang, 2)        hang                3
# guó        (g, uo, 2)         guo                 3
# hòng       (h, ong, 4)        hong                3
# zèng       (z, eng, 4)        zeng                3
# shǒu       (sh, ou, 5)        shou                3
# yé         (y, e, 2)          ye                  3
# shǎn       (sh, an, 3)        shan                3
# hài        (h, ai, 5)         hai                 3
# gào        (g, ao, 5)         gao                 3
# zāo        (z, ao, 5)         zao                 3
# huāng      (h, uang, 1)       huang               3
# huān       (h, uan, 1)        huan                3
# gè         (g, e, 4)          ge                  3
# gèn        (g, en, 4)         gen                 3
# sāi        (s, ai, 5)         sai                 3
# gāi        (g, ai, 5)         gai                 3
# nào        (n, ao, 5)         nao                 3
# tuí        (t, ui, 2)         tui                 3
# sān        (s, an, 1)         san                 3
# zǎn        (z, an, 3)         zan                 3
# tǒng       (t, ong, 3)        tong                3
# wà         (w, a, 4)          wa                  3
# chū        (ch, u, 1)         chu                 3
# chóng      (ch, ong, 2)       chong               3
# chái       (ch, ai, 5)        chai                3
# chuō       (ch, uo, 1)        chuo                3
# chuáng     (ch, uang, 2)      chuang              3
# bǔ         (b, u, 3)          bu                  3
# bǎng       (b, ang, 3)        bang                3
# xiáo       (x, iao, 5)        xiao                3
# bū         (b, u, 1)          bu                  3
# bīng       (b, ing, 1)        bing                3
# běng       (b, eng, 3)        beng                3
# bēng       (b, eng, 1)        beng                3
# bò         (b, o, 4)          bo                  3
# bá         (b, a, 2)          ba                  3
# bài        (b, ai, 5)         bai                 3
# xuē        (x, ue, 1)         xue                 3
# ǎo         (, ao, 5)          ao                  3
# xuǎn       (x, uan, 3)        xuan                3
# biào       (b, iao, 5)        biao                3
# tǎng       (t, ang, 3)        tang                3
# tū         (t, u, 1)          tu                  3
# áng        (, ang, 2)         ang                 3
# tiē        (t, ie, 1)         tie                 3
# dǎng       (d, ang, 3)        dang                3
# zǒng       (z, ong, 3)        zong                3
# sūn        (s, un, 1)         sun                 3
# sǎn        (s, an, 3)         san                 3
# dēng       (d, eng, 1)        deng                3
# dāo        (d, ao, 5)         dao                 3
# sǔn        (s, un, 3)         sun                 3
# tiào       (t, iao, 5)        tiao                3
# tiāo       (t, iao, 5)        tiao                3
# rén        (r, en, 2)         ren                 3
# cài        (c, ai, 5)         cai                 3
# duò        (d, uo, 4)         duo                 3
# diē        (d, ie, 1)         die                 3
# tuǒ        (t, uo, 3)         tuo                 3
# cǎo        (c, ao, 5)         cao                 3
# cū         (c, u, 1)          cu                  3
# tè         (t, e, 4)          te                  3
# céng       (c, eng, 2)        ceng                3
# tóu        (t, ou, 5)         tou                 3
# tù         (t, u, 4)          tu                  3
# hē         (h, e, 1)          he                  3
# xìn        (x, in, 4)         xin                 3
# nǐ         (n, i, 3)          ni                  3
# qǔ         (q, u, 3)          qu                  3
# mǎng       (m, ang, 3)        mang                3
# nǎo        (n, ao, 5)         nao                 3
# lǐn        (l, in, 3)         lin                 3
# lǐng       (l, ing, 3)        ling                3
# lǘ         (l, ü, 2)          lv                  3
# kuān       (k, uan, 1)        kuan                3
# zhǎng      (zh, ang, 3)       zhang               3
# pián       (p, ian, 2)        pian                3
# zhǎo       (zh, ao, 5)        zhao                3
# liù        (l, iu, 4)         liu                 3
# liào       (l, iao, 5)        liao                3
# piān       (p, ian, 1)        pian                3
# piāo       (p, iao, 5)        piao                3
# kuǐ        (k, ui, 3)         kui                 3
# zhǒu       (zh, ou, 5)        zhou                3
# kǒng       (k, ong, 3)        kong                3
# kě         (k, e, 3)          ke                  3
# lìng       (l, ing, 4)        ling                3
# kēng       (k, eng, 1)        keng                3
# quǎn       (q, uan, 3)        quan                3
# má         (m, a, 2)          ma                  3
# quān       (q, uan, 1)        quan                3
# pá         (p, a, 2)          pa                  3
# qǐn        (q, in, 3)         qin                 3
# qiǎng      (q, iang, 3)       qiang               3
# póu        (p, ou, 5)         pou                 3
# zhě        (zh, e, 3)         zhe                 3
# ruǎn       (r, uan, 3)        ruan                3
# ruǐ        (r, ui, 3)         rui                 3
# jiǎng      (j, iang, 3)       jiang               3
# pó         (p, o, 2)          po                  3
# lüè        (l, üe, 4)         lve                 3
# juǎn       (j, uan, 3)        juan                3
# nuǎn       (n, uan, 3)        nuan                3
# zhá        (zh, a, 2)         zha                 3
# làng       (l, ang, 4)        lang                3
# niàn       (n, ian, 4)        nian                3
# zhài       (zh, ai, 5)        zhai                3
# zàng       (z, ang, 4)        zang                3
# rán        (r, an, 2)         ran                 3
# hǔ         (h, u, 3)          hu                  3
# cǐ         (c, i, 3)          ci                  2
# tōng       (t, ong, 1)        tong                2
# zhāi       (zh, ai, 5)        zhai                2
# de         (d, e, 5)          de                  2
# tōu        (t, ou, 5)         tou                 2
# cuǐ        (c, ui, 3)         cui                 2
# pān        (p, an, 1)         pan                 2
# pāo        (p, ao, 5)         pao                 2
# tǎ         (t, a, 3)          ta                  2
# cuó        (c, uo, 2)         cuo                 2
# mèn        (m, en, 4)         men                 2
# xǔ         (x, u, 3)          xu                  2
# cāi        (c, ai, 5)         cai                 2
# tī         (t, i, 1)          ti                  2
# cāo        (c, ao, 5)         cao                 2
# cú         (c, u, 2)          cu                  2
# cùn        (c, un, 4)         cun                 2
# lǎo        (l, ao, 5)         lao                 2
# tòng       (t, ong, 4)        tong                2
# chǔn       (ch, un, 3)        chun                2
# pìn        (p, in, 4)         pin                 2
# cén        (c, en, 2)         cen                 2
# cǎn        (c, an, 3)         can                 2
# tā         (t, a, 1)          ta                  2
# pén        (p, en, 2)         pen                 2
# miào       (m, iao, 5)        miao                2
# tāng       (t, ang, 1)        tang                2
# miáo       (m, iao, 5)        miao                2
# cún        (c, un, 2)         cun                 2
# hǎo        (h, ao, 5)         hao                 2
# wáng       (w, ang, 2)        wang                2
# mèng       (m, eng, 4)        meng                2
# ē          (, e, 1)           e                   2
# nǔ         (n, u, 3)          nu                  2
# chuàn      (ch, uan, 4)       chuan               2
# bǒ         (b, o, 3)          bo                  2
# mǎo        (m, ao, 5)         mao                 2
# nüè        (n, üe, 4)         nve                 2
# xiòng      (x, iong, 4)       xiong               2
# xióng      (x, iong, 2)       xiong               2
# bī         (b, i, 1)          bi                  2
# běn        (b, en, 3)         ben                 2
# bēn        (b, en, 1)         ben                 2
# bèn        (b, en, 4)         ben                 2
# báo        (b, ao, 5)         bao                 2
# niáng      (n, iang, 2)       niang               2
# nìng       (n, ing, 4)        ning                2
# ǎn         (, an, 3)          an                  2
# xuè        (x, ue, 4)         xue                 2
# biǎo       (b, iao, 5)        biao                2
# biē        (b, ie, 1)         bie                 2
# nèn        (n, en, 4)         nen                 2
# niǔ        (n, iu, 3)         niu                 2
# nuò        (n, uo, 4)         nuo                 2
# wǒ         (w, o, 3)          wo                  2
# chuān      (ch, uan, 1)       chuan               2
# mén        (m, en, 2)         men                 2
# piàn       (p, ian, 4)        pian                2
# tǔ         (t, u, 3)          tu                  2
# èr         (, er, 4)          er                  2
# pài        (p, ai, 5)         pai                 2
# chūn       (ch, un, 1)        chun                2
# pà         (p, a, 4)          pa                  2
# chōu       (ch, ou, 5)        chou                2
# chěng      (ch, eng, 3)       cheng               2
# piǎo       (p, iao, 5)        piao                2
# chē        (ch, e, 1)         che                 2
# wèn        (w, en, 4)         wen                 2
# wèng       (w, eng, 4)        weng                2
# chāi       (ch, ai, 5)        chai                2
# zhóu       (zh, ou, 5)        zhou                2
# mā         (m, a, 1)          ma                  2
# piáo       (p, iao, 5)        piao                2
# wāng       (w, ang, 1)        wang                2
# chàn       (ch, an, 4)        chan                2
# wēng       (w, eng, 1)        weng                2
# chuǎn      (ch, uan, 3)       chuan               2
# māo        (m, ao, 5)         mao                 2
# chuī       (ch, ui, 1)        chui                2
# duó        (d, uo, 2)         duo                 2
# zǔn        (z, un, 3)         zun                 2
# duān       (d, uan, 1)        duan                2
# shāi       (sh, ai, 5)        shai                2
# kuā        (k, ua, 1)         kua                 2
# shé        (sh, e, 2)         she                 2
# shén       (sh, en, 2)        shen                2
# huài       (h, uai, 5)        huai                2
# gǎng       (g, ang, 3)        gang                2
# zòng       (z, ong, 4)        zong                2
# qún        (q, un, 2)         qun                 2
# gě         (g, e, 3)          ge                  2
# gēn        (g, en, 1)         gen                 2
# zuǒ        (z, uo, 3)         zuo                 2
# huā        (h, ua, 1)         hua                 2
# zā         (z, a, 1)          za                  2
# tuán       (t, uan, 2)        tuan                2
# kài        (k, ai, 5)         kai                 2
# shěng      (sh, eng, 3)       sheng               2
# kào        (k, ao, 5)         kao                 2
# zuǎn       (z, uan, 3)        zuan                2
# gàng       (g, ang, 4)        gang                2
# shǎng      (sh, ang, 3)       shang               2
# zuó        (z, uo, 2)         zuo                 2
# huó        (h, uo, 2)         huo                 2
# qūn        (q, un, 1)         qun                 2
# suàn       (s, uan, 4)        suan                2
# hāi        (h, ai, 5)         hai                 2
# hǎi        (h, ai, 5)         hai                 2
# rì         (r, i, 4)          ri                  2
# zá         (z, a, 2)          za                  2
# hēi        (h, ei, 5)         hei                 2
# hāo        (h, ao, 5)         hao                 2
# rùn        (r, un, 4)         run                 2
# jiě        (j, ie, 3)         jie                 2
# rào        (r, ao, 5)         rao                 2
# rǎng       (r, ang, 3)        rang                2
# zè         (z, e, 4)          ze                  2
# kuáng      (k, uang, 2)       kuang               2
# shuài      (sh, uai, 5)       shuai               2
# ruí        (r, ui, 2)         rui                 2
# yóng       (y, ong, 2)        yong                2
# kuà        (k, ua, 4)         kua                 2
# qǐng       (q, ing, 3)        qing                2
# shuǎng     (sh, uang, 3)      shuang              2
# huǒ        (h, uo, 3)         huo                 2
# huō        (h, uo, 1)         huo                 2
# shàng      (sh, ang, 4)       shang               2
# quàn       (q, uan, 4)        quan                2
# shě        (sh, e, 3)         she                 2
# kā         (k, a, 1)          ka                  2
# sēng       (s, eng, 1)        seng                2
# dū         (d, u, 1)          du                  2
# dōu        (d, ou, 5)         dou                 2
# qià        (q, ia, 4)         qia                 2
# liǎng      (l, iang, 3)       liang               2
# suí        (s, ui, 2)         sui                 2
# yuǎn       (y, uan, 3)        yuan                2
# sǎo        (s, ao, 5)         sao                 2
# yuē        (y, ue, 1)         yue                 2
# zhǎ        (zh, a, 3)         zha                 2
# yǎ         (y, a, 3)          ya                  2
# làn        (l, an, 4)         lan                 2
# dāi        (d, ai, 5)         dai                 2
# lào        (l, ao, 5)         lao                 2
# tiè        (t, ie, 4)         tie                 2
# tiān       (t, ian, 1)        tian                2
# lè         (l, e, 4)          le                  2
# léng       (l, eng, 2)        leng                2
# tiě        (t, ie, 3)         tie                 2
# duǒ        (d, uo, 3)         duo                 2
# tiǎo       (t, iao, 5)        tiao                2
# hǎn        (h, an, 3)         han                 2
# liǎn       (l, ian, 3)        lian                2
# sǎ         (s, a, 3)          sa                  2
# gòng       (g, ong, 4)        gong                2
# zǎi        (z, ai, 5)         zai                 2
# sài        (s, ai, 5)         sai                 2
# zū         (z, u, 1)          zu                  2
# kāi        (k, ai, 5)         kai                 2
# fǒu        (f, ou, 5)         fou                 2
# sào        (s, ao, 5)         sao                 2
# qiǎo       (q, iao, 5)        qiao                2
# fā         (f, a, 1)          fa                  2
# fà         (f, a, 4)          fa                  2
# dǔn        (d, un, 3)         dun                 2
# suān       (s, uan, 1)        suan                2
# dǐng       (d, ing, 3)        ding                2
# ya         (y, a, 5)          ya                  1
# àng        (, ang, 4)         ang                 1
# zhuā       (zh, ua, 1)        zhua                1
# záo        (z, ao, 5)         zao                 1
# zuō        (z, uo, 1)         zuo                 1
# zhē        (zh, e, 1)         zhe                 1
# xín        (x, in, 2)         xin                 1
# xǐng       (x, ing, 3)        xing                1
# zuān       (z, uan, 1)        zuan                1
# ō          (, o, 1)           o                   1
# zǎ         (z, a, 3)          za                  1
# xú         (x, u, 2)          xu                  1
# zèn        (z, en, 4)         zen                 1
# zǒu        (z, ou, 5)         zou                 1
# āo         (, ao, 5)          ao                  1
# án         (, an, 2)          an                  1
# zhe        (zh, e, 5)         zhe                 1
# zhuài      (zh, uai, 5)       zhuai               1
# ēn         (, en, 1)          en                  1
# zhǎi       (zh, ai, 5)        zhai                1
# ě          (, e, 3)           e                   1
# zān        (z, an, 1)         zan                 1
# ā          (, a, 1)           a                   1
# zéi        (z, ei, 5)         zei                 1
# ó          (, o, 2)           o                   1
# zhuǎn      (zh, uan, 3)       zhuan               1
# yòng       (y, ong, 4)        yong                1
# zòu        (z, ou, 5)         zou                 1
# zuǐ        (z, ui, 3)         zui                 1
# zhái       (zh, ai, 5)        zhai                1
# a          (, a, 5)           a                   1
# xuě        (x, ue, 3)         xue                 1
# kǒu        (k, ou, 5)         kou                 1
# kōu        (k, ou, 5)         kou                 1
# kēi        (k, ei, 5)         kei                 1
# kāo        (k, ao, 5)         kao                 1
# kùn        (k, un, 4)         kun                 1
# kòng       (k, ong, 4)        kong                1
# ké         (k, e, 2)          ke                  1
# káng       (k, ang, 2)        kang                1
# kuǎn       (k, uan, 3)        kuan                1
# kuǎi       (k, uai, 5)        kuai                1
# kuǎ        (k, ua, 3)         kua                 1
# juē        (j, ue, 1)         jue                 1
# hǒu        (h, ou, 5)         hou                 1
# hěn        (h, en, 3)         hen                 1
# hēng       (h, eng, 1)        heng                1
# hāng       (h, ang, 1)        hang                1
# hā         (h, a, 1)          ha                  1
# hén        (h, en, 2)         hen                 1
# hèn        (h, en, 4)         hen                 1
# há         (h, a, 2)          ha                  1
# hàng       (h, ang, 4)        hang                1
# huǎn       (h, uan, 3)        huan                1
# kǎ         (k, a, 3)          ka                  1
# kǔ         (k, u, 3)          ku                  1
# xiǔ        (x, iu, 3)         xiu                 1
# le         (l, e, 5)          le                  1
# mo         (m, o, 5)          mo                  1
# miù        (m, iu, 4)         miu                 1
# men        (m, en, 5)         men                 1
# lǒu        (l, ou, 5)         lou                 1
# lǎng       (l, ang, 3)        lang                1
# lǎ         (l, a, 3)          la                  1
# lūn        (l, un, 1)         lun                 1
# lī         (l, i, 1)          li                  1
# lěng       (l, eng, 3)        leng                1
# lēi        (l, ei, 5)         lei                 1
# lāo        (l, ao, 5)         lao                 1
# lā         (l, a, 1)          la                  1
# lùn        (l, un, 4)         lun                 1
# luǎn       (l, uan, 3)        luan                1
# luō        (l, uo, 1)         luo                 1
# luàn       (l, uan, 4)        luan                1
# liǔ        (l, iu, 3)         liu                 1
# liǎo       (l, iao, 5)        liao                1
# liǎ        (l, ia, 3)         lia                 1
# liū        (l, iu, 1)         liu                 1
# liāo       (l, iao, 5)        liao                1
# gǎi        (g, ai, 5)         gai                 1
# gěn        (g, en, 3)         gen                 1
# gěi        (g, ei, 5)         gei                 1
# gā         (g, a, 1)          ga                  1
# cáng       (c, ang, 2)        cang                1
# cà         (c, a, 4)          ca                  1
# cuán       (c, uan, 2)        cuan                1
# chǒng      (ch, ong, 3)       chong               1
# chǎo       (ch, ao, 5)        chao                1
# chǎi       (ch, ai, 5)        chai                1
# chě        (ch, e, 3)         che                 1
# chòu       (ch, ou, 5)        chou                1
# chòng      (ch, ong, 4)       chong               1
# chèng      (ch, eng, 4)       cheng               1
# chào       (ch, ao, 5)        chao                1
# chuǎng     (ch, uang, 3)      chuang              1
# chuāi      (ch, uai, 5)       chuai               1
# chuài      (ch, uai, 5)       chuai               1
# bǎ         (b, a, 3)          ba                  1
# běi        (b, ei, 5)         bei                 1
# bí         (b, i, 2)          bi                  1
# bèng       (b, eng, 4)        beng                1
# bái        (b, ai, 5)         bai                 1
# bo         (b, o, 5)          bo                  1
# bié        (b, ie, 2)         bie                 1
# cā         (c, a, 1)          ca                  1
# cī         (c, i, 1)          ci                  1
# cǔn        (c, un, 3)         cun                 1
# fěng       (f, eng, 3)        feng                1
# gú         (g, u, 2)          gu                  1
# gùn        (g, un, 4)         gun                 1
# gèng       (g, eng, 4)        geng                1
# gá         (g, a, 2)          ga                  1
# guǎi       (g, uai, 5)        guai                1
# guǎ        (g, ua, 3)         gua                 1
# guāi       (g, uai, 5)        guai                1
# guò        (g, uo, 4)         guo                 1
# fǎ         (f, a, 3)          fa                  1
# fěn        (f, en, 3)         fen                 1
# diū        (d, iu, 1)         diu                 1
# fàng       (f, ang, 4)        fang                1
# dǒng       (d, ong, 3)        dong                1
# dǎi        (d, ai, 5)         dai                 1
# dǎ         (d, a, 3)          da                  1
# děng       (d, eng, 3)        deng                1
# dā         (d, a, 1)          da                  1
# dà         (d, a, 4)          da                  1
# duǎn       (d, uan, 3)        duan                1
# duī        (d, ui, 1)         dui                 1
# mà         (m, a, 4)          ma                  1
# mái        (m, ai, 5)         mai                 1
# mìng       (m, ing, 4)        ming                1
# réng       (r, eng, 2)        reng                1
# sòu        (s, ou, 5)         sou                 1
# sàng       (s, ang, 4)        sang                1
# sàn        (s, an, 4)         san                 1
# suǐ        (s, ui, 3)         sui                 1
# shǔn       (sh, un, 3)        shun                1
# shǎo       (sh, ao, 5)        shao                1
# shōu       (sh, ou, 5)        shou                1
# shē        (sh, e, 1)         she                 1
# shéng      (sh, eng, 2)       sheng               1
# shài       (sh, ai, 5)        shai                1
# shuǐ       (sh, ui, 3)        shui                1
# shuō       (sh, uo, 1)        shuo                1
# shuān      (sh, uan, 1)       shuan               1
# shuāi      (sh, uai, 5)       shuai               1
# shuā       (sh, ua, 1)        shua                1
# shuí       (sh, ui, 2)        shui                1
# shi        (sh, i, 5)         shi                 1
# shang      (sh, ang, 5)       shang               1
# rǒng       (r, ong, 3)        rong                1
# rǎo        (r, ao, 5)         rao                 1
# rě         (r, e, 3)          re                  1
# sú         (s, u, 2)          su                  1
# sā         (s, a, 1)          sa                  1
# sāng       (s, ang, 1)        sang                1
# tāi        (t, ai, 5)         tai                 1
# xiě        (x, ie, 3)         xie                 1
# wǎi        (w, ai, 5)         wai                 1
# wǎ         (w, a, 3)          wa                  1
# wěng       (w, eng, 3)        weng                1
# wāi        (w, ai, 5)         wai                 1
# wá         (w, a, 2)          wa                  1
# wài        (w, ai, 5)         wai                 1
# wa         (w, a, 5)          wa                  1
# tǎo        (t, ao, 5)         tao                 1
# tòu        (t, ou, 5)         tou                 1
# sēn        (s, en, 1)         sen                 1
# tào        (t, ao, 5)         tao                 1
# tàng       (t, ang, 4)        tang                1
# tuǐ        (t, ui, 3)         tui                 1
# tuī        (t, ui, 1)         tui                 1
# tuān       (t, uan, 1)        tuan                1
# tuàn       (t, uan, 4)        tuan                1
# tiàn       (t, ian, 4)        tian                1
# sǐ         (s, i, 3)          si                  1
# sǎng       (s, ang, 3)        sang                1
# ròu        (r, ou, 5)         rou                 1
# rèng       (r, eng, 4)        reng                1
# mān        (m, an, 1)         man                 1
# rè         (r, e, 4)          re                  1
# nù         (n, u, 4)          nu                  1
# nòu        (n, ou, 5)         nou                 1
# nòng       (n, ong, 4)        nong                1
# néng       (n, eng, 2)        neng                1
# nèi        (n, ei, 5)         nei                 1
# nè         (n, e, 4)          ne                  1
# náng       (n, ang, 2)        nang                1
# ná         (n, a, 2)          na                  1
# bei        (b, ei, 5)         bei                 1
# niān       (n, ian, 1)        nian                1
# niú        (n, iu, 2)         niu                 1
# niào       (n, iao, 5)        niao                1
# niàng      (n, iang, 4)       niang               1
# ne         (n, e, 5)          ne                  1
# mǒu        (m, ou, 5)         mou                 1
# mǒ         (m, o, 3)          mo                  1
# mǐng       (m, ing, 3)        ming                1
# mǎn        (m, an, 3)         man                 1
# mǎi        (m, ai, 5)         mai                 1
# mō         (m, o, 1)          mo                  1
# měng       (m, eng, 3)        meng                1
# něi        (n, ei, 5)         nei                 1
# nǎn        (n, an, 3)         nan                 1
# nǎng       (n, ang, 3)        nang                1
# pīng       (p, ing, 1)        ping                1
# ràng       (r, ang, 4)        rang                1
# ruán       (r, uan, 2)        ruan                1
# qìn        (q, in, 4)         qin                 1
# quē        (q, ue, 1)         que                 1
# qiǔ        (q, iu, 3)         qiu                 1
# qiě        (q, ie, 3)         qie                 1
# pǒ         (p, o, 3)          po                  1
# pǐn        (p, in, 3)         pin                 1
# pōu        (p, ou, 5)         pou                 1
# pěng       (p, eng, 3)        peng                1
# nǚ         (n, ü, 3)          nv                  1
# pēn        (p, en, 1)         pen                 1
# pēi        (p, ei, 5)         pei                 1
# pāng       (p, ang, 1)        pang                1
# pāi        (p, ai, 5)         pai                 1
# pā         (p, a, 1)          pa                  1
# pàng       (p, ang, 4)        pang                1
# piǎn       (p, ian, 3)        pian                1
# piē        (p, ie, 1)         pie                 1
# nǜ         (n, ü, 4)          nv                  1
# niē        (n, ie, 1)         nie                 1
# Name: count, dtype: int64

# %%
import pykakasi

# New-style converter
kks = pykakasi.kakasi()
converter = kks.convert

SMALL_KANA = "ァィゥェォャュョヮヵヶ"
SOKUON = "ッ"
CHOONPU = "ー"

def decompose_katakana(word):
    morae = []
    i = 0
    while i < len(word):
        ch = word[i]
        if ch == SOKUON or ch == CHOONPU:
            morae.append(ch)
            i += 1
        elif i + 1 < len(word) and word[i + 1] in SMALL_KANA:
            morae.append(ch + word[i + 1])
            i += 2
        else:
            morae.append(ch)
            i += 1
    return morae

def katakana_to_romaji_tuple(word):
    morae = decompose_katakana(word)
    romaji = []
    for m in morae:
        result = converter(m)
        if result:
            romaji.append(result[0]['hepburn'])
        else:
            romaji.append(m)  # fallback for symbols like ッ or ー
    return "".join(romaji)


df["katakana_romaji"] = df["kJapanese"].apply(katakana_to_romaji_tuple)

df[["kJapanese", "katakana_romaji"]].value_counts()
# Out:
# kJapanese  katakana_romaji
# コウ         kou                272
# ショウ        shou               191
# シ          shi                168
# カン         kan                161
# キ          ki                 160
# セン         sen                142
# ソウ         sou                139
# トウ         tou                139
# ケン         ken                111
# ケイ         kei                109
# キョウ        kyou               108
# カ          ka                 103
# ホウ         hou                 95
# エン         en                  94
# カイ         kai                 93
# シン         shin                89
# ヨウ         you                 89
# ヒ          hi                  86
# チョウ        chou                83
# イ          i                   81
# セイ         sei                 80
# シュウ        shuu                79
# テイ         tei                 75
# コ          ko                  68
# サン         san                 66
# タン         tan                 65
# キュウ        kyuu                64
# フ          fu                  63
# サイ         sai                 63
# ボウ         bou                 61
# カク         kaku                59
# ハン         han                 56
# ジョウ        jou                 55
# キン         kin                 54
# エイ         ei                  53
# オウ         ou                  51
# リョウ        ryou                50
# イン         in                  49
# ユウ         yuu                 48
# ロウ         rou                 47
# レイ         rei                 47
# テン         ten                 47
# タイ         tai                 46
# ソ          so                  45
# ジ          ji                  43
# コン         kon                 42
# チュウ        chuu                41
# スイ         sui                 40
# ガイ         gai                 40
# サ          sa                  38
# セキ         seki                37
# シュ         shu                 37
# ク          ku                  37
# ドウ         dou                 37
# ビ          bi                  36
# ヘイ         hei                 36
# ヒョウ        hyou                36
# ゲン         gen                 36
# カツ         katsu               34
# リン         rin                 34
# ハイ         hai                 34
# ハク         haku                34
# キョ         kyo                 33
# リ          ri                  33
# ロ          ro                  32
# シャ         sha                 32
# チ          chi                 31
# ゴ          go                  30
# ジン         jin                 30
# ジュン        jun                 30
# ヘン         hen                 29
# サク         saku                29
# レン         ren                 29
# シュン        shun                28
# セツ         setsu               28
# ユ          yu                  28
# ラン         ran                 28
# ケツ         ketsu               27
# ガ          ga                  27
# ゴウ         gou                 27
# ショ         sho                 27
# ショク        shoku               27
# ヒン         hin                 26
# ハ          ha                  26
# ト          to                  25
# フン         fun                 25
# タク         taku                25
# ウ          u                   23
# シツ         shitsu              23
# フク         fuku                23
# ギ          gi                  23
# リュウ        ryuu                22
# ガン         gan                 22
# ライ         rai                 22
# ビン         bin                 22
# タ          ta                  22
# ソン         son                 21
# ホ          ho                  21
# ウン         un                  21
# ジョ         jo                  21
# バイ         bai                 20
# シャク        shaku               20
# ギョウ        gyou                20
# テキ         teki                19
# コク         koku                19
# ジュウ        juu                 19
# アイ         ai                  19
# ガク         gaku                19
# テツ         tetsu               18
# アン         an                  17
# ヒツ         hitsu               17
# ゼン         zen                 17
# チン         chin                17
# クン         kun                 17
# ボク         boku                17
# トク         toku                17
# ダ          da                  16
# ソク         soku                16
# ベン         ben                 16
# エキ         eki                 16
# ブ          bu                  16
# チョ         cho                 16
# ヨ          yo                  16
# シュク        shuku               16
# モウ         mou                 16
# キツ         kitsu               16
# マン         man                 15
# ア          a                   15
# バン         ban                 15
# トン         ton                 15
# ロク         roku                15
# ジュ         ju                  15
# ラ          ra                  14
# バク         baku                14
# ボ          bo                  14
# ビョウ        byou                14
# メイ         mei                 14
# サツ         satsu               14
# ダイ         dai                 13
# イツ         itsu                13
# ザン         zan                 13
# ゲイ         gei                 13
# ヤク         yaku                13
# ギン         gin                 13
# ゼイ         zei                 12
# ダン         dan                 12
# グ          gu                  11
# イク         iku                 11
# ゲキ         geki                11
# ヘキ         heki                11
# ド          do                  11
# コツ         kotsu               11
# オ          o                   11
# キョク        kyoku               10
# ヤ          ya                  10
# オン         on                  10
# デン         den                 10
# ヨク         yoku                10
# ワイ         wai                  9
# フツ         futsu                9
# レキ         reki                 9
# アク         aku                  9
# クツ         kutsu                9
# ゾウ         zou                  9
# ネン         nen                  9
# ルイ         rui                  9
# ジャク        jaku                 9
# ハツ         hatsu                9
# ベツ         betsu                9
# ワン         wan                  8
# チョク        choku                8
# スウ         suu                  8
# アツ         atsu                 8
# エツ         etsu                 8
# ル          ru                   8
# リョ         ryo                  8
# ギョ         gyo                  8
# ラク         raku                 8
# ム          mu                   8
# マイ         mai                  8
# ノウ         nou                  8
# ズイ         zui                  8
# チク         chiku                8
# ボツ         botsu                7
# モン         mon                  7
# キク         kiku                 7
# タツ         tatsu                7
# グウ         guu                  7
# フウ         fuu                  7
# ゾク         zoku                 7
# ツイ         tsui                 7
# ジュツ        jutsu                7
# メン         men                  7
# ドン         don                  6
# マ          ma                   6
# リツ         ritsu                6
# バツ         batsu                6
# ホン         hon                  6
# バ          ba                   6
# マツ         matsu                6
# レツ         retsu                6
# ワ          wa                   6
# ブン         bun                  6
# モ          mo                   5
# ベキ         beki                 5
# チツ         chitsu               5
# ジョク        joku                 5
# ジク         jiku                 5
# ゲツ         getsu                5
# トツ         totsu                5
# ナン         nan                  5
# ザ          za                   5
# ジツ         jitsu                5
# ス          su                   5
# ニン         nin                  5
# ネイ         nei                  5
# ダツ         datsu                5
# ジャ         ja                   4
# ミ          mi                   4
# グン         gun                  4
# モク         moku                 4
# ザイ         zai                  4
# ボン         bon                  4
# ソツ         sotsu                4
# ケ          ke                   4
# リク         riku                 4
# ギャク        gyaku                4
# ロン         ron                  4
# リョク        ryoku                4
# エ          e                    4
# ハチ         hachi                4
# オク         oku                  4
# ミン         min                  3
# ワク         waku                 3
# ゼツ         zetsu                3
# ウツ         utsu                 3
# ミツ         mitsu                3
# オツ         otsu                 3
# ギュウ        gyuu                 3
# シュツ        shutsu               3
# シキ         shiki                3
# カチ         kachi                3
# キャク        kyaku                3
# リャク        ryaku                3
# ケチ         kechi                3
# ベイ         bei                  3
# ネツ         netsu                3
# ヘツ         hetsu                3
# ニ          ni                   3
# チャク        chaku                3
# チュン        chun                 3
# チュ         chu                  3
# ドク         doku                 3
# ゴン         gon                  2
# キャ         kya                  2
# デキ         deki                 2
# ニョウ        nyou                 2
# デ          de                   2
# ツウ         tsuu                 2
# ニャク        nyaku                2
# ケキ         keki                 2
# ギョク        gyoku                2
# ラツ         ratsu                2
# ミャク        myaku                2
# ニュウ        nyuu                 2
# デイ         dei                  2
# ミョウ        myou                 2
# ジュク        juku                 2
# ダク         daku                 2
# ブツ         butsu                2
# ズ          zu                   2
# セチ         sechi                2
# ゼ          ze                   2
# マク         maku                 2
# イキ         iki                  2
# やま         yama                 1
# ワツ         watsu                1
# ナ          na                   1
# ヒチ         hichi                1
# ノット        notsuto              1
# ナイ         nai                  1
# ナツ         natsu                1
# ギツ         gitsu                1
# ネ          ne                   1
# ニク         niku                 1
# イチ         ichi                 1
# キチ         kichi                1
# ニチ         nichi                1
# ウイ         ui                   1
# レ          re                   1
# ウチ         uchi                 1
# ハウ         hau                  1
# クウ         kuu                  1
# ゴク         goku                 1
# ラチ         rachi                1
# フチ         fuchi                1
# タチ         tachi                1
# チャ         cha                  1
# ソチ         sochi                1
# ヘ          he                   1
# ホク         hoku                 1
# ホツ         hotsu                1
# セ          se                   1
# スン         sun                  1
# ノ          no                   1
# ブク         buku                 1
# チュツ        chutsu               1
# メ          me                   1
# ヒャク        hyaku                1
# メツ         metsu                1
# シチ         shichi               1
# モチ         mochi                1
# デツ         detsu                1
# ビュウ        byuu                 1
# まろ         maro                 1
# ユイ         yui                  1
# コチ         kochi                1
# ゲ          ge                   1
# ドツ         dotsu                1
# ヒュウ        hyuu                 1
# ぬた         nuta                 1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                          kDefinition Character kMandarin  \
# 0                                  one; a, an; alone         一        yī
# 1    male adult; robust, vigorous; 4th heavenly stem         丁      dīng
# 2                                              seven         七        qī
# 3                          ten thousand; innumerable         万       wàn
# 4  unit of length equal 3.3 meters; gentleman, ma...         丈     zhàng
#
#   kHangul kKorean kJapanese kJapaneseOn decomposed_hangul decomposed_pinyin  \
# 0       일      IL        イチ        ICHI         (ㅇ, ㅣ, ㄹ)         (y, i, 1)
# 1       정    CENG       チョウ         TEI         (ㅈ, ㅓ, ㅇ)       (d, ing, 1)
# 2       칠    CHIL        シチ      SHICHI         (ㅊ, ㅣ, ㄹ)         (q, i, 1)
# 3       만     MAN        マン         MAN         (ㅁ, ㅏ, ㄴ)        (w, an, 4)
# 4       장    CANG       ジョウ         JOU         (ㅈ, ㅏ, ㅇ)      (zh, ang, 4)
#
#   katakana_romaji pinyin_without_accent
# 0            ichi                    yi
# 1            chou                  ding
# 2          shichi                    qi
# 3             man                   wan
# 4             jou                 zhang

# %%
df.to_pickle("triolingo.pkl.xz")

# %%
# katakana_romaji
# decomposed_pinyin
# decomposed_hangul
# kMandarin
# kHangul
# toneless_pinyin

def inequality_score(lst):
    n = len(lst)
    sorted_lst = sorted(lst)
    cumulative = 0
    for i, val in enumerate(sorted_lst):
        cumulative += (2 * (i + 1) - n - 1) * val
    gini = cumulative / (n * sum(lst))
    
    scaled_capped_sum = min(5, sum(lst)) / 5
    return gini * scaled_capped_sum

INPUT = "toneless_pinyin"
OUTPUT = "katakana_romaji"

results = df.groupby(INPUT).apply(lambda s: pd.Series({
    "inequality_score": inequality_score(np.unique(s[OUTPUT], return_counts = True)[1]),
    "max_proportion": max(np.unique(s[OUTPUT], return_counts = True)[1] / len(s[OUTPUT])),
    "sum_squared_proportion": sum(np.square(np.unique(s[OUTPUT], return_counts = True)[1] / len(s[OUTPUT]))),
    "distribution": s[OUTPUT].value_counts().to_dict()
}), include_groups = False).sort_values("inequality_score", ascending = False)

results[["inequality_score", "max_proportion", "sum_squared_proportion"]] = results[
    ["inequality_score", "max_proportion", "sum_squared_proportion"]
].apply(lambda x: x.round(2))

results
# Out:
#                  inequality_score  max_proportion  sum_squared_proportion  \
# toneless_pinyin
# fu                           0.71            0.55                    0.37
# li                           0.66            0.41                    0.28
# huan                         0.65            0.79                    0.64
# qi                           0.64            0.51                    0.28
# wei                          0.64            0.59                    0.37
# jin                          0.63            0.56                    0.37
# han                          0.63            0.87                    0.76
# shen                         0.63            0.77                    0.60
# you                          0.63            0.83                    0.71
# gu                           0.63            0.77                    0.61
# pi                           0.62            0.62                    0.43
# jia                          0.62            0.64                    0.44
# huang                        0.62            0.83                    0.71
# fan                          0.61            0.72                    0.54
# ban                          0.61            0.86                    0.74
# mao                          0.61            0.72                    0.54
# yuan                         0.61            0.63                    0.46
# yi                           0.60            0.32                    0.15
# yin                          0.60            0.67                    0.51
# yao                          0.60            0.69                    0.51
# di                           0.60            0.51                    0.34
# si                           0.60            0.73                    0.56
# fen                          0.60            0.83                    0.69
# hong                         0.60            0.76                    0.59
# jiu                          0.59            0.69                    0.50
# zhi                          0.59            0.40                    0.20
# ji                           0.58            0.36                    0.16
# shi                          0.58            0.45                    0.23
# yan                          0.58            0.65                    0.46
# dai                          0.58            0.78                    0.62
# xian                         0.58            0.37                    0.26
# tang                         0.57            0.82                    0.69
# xiao                         0.57            0.51                    0.36
# hui                          0.57            0.40                    0.25
# an                           0.57            0.74                    0.56
# wu                           0.57            0.38                    0.21
# liao                         0.57            0.90                    0.82
# zao                          0.57            0.79                    0.64
# xi                           0.57            0.27                    0.14
# bi                           0.56            0.41                    0.26
# ying                         0.56            0.60                    0.41
# bo                           0.56            0.49                    0.29
# lu                           0.56            0.62                    0.45
# qian                         0.56            0.38                    0.28
# peng                         0.56            0.89                    0.80
# chi                          0.55            0.41                    0.25
# liu                          0.55            0.88                    0.79
# ting                         0.55            0.68                    0.50
# jing                         0.55            0.36                    0.27
# bao                          0.55            0.64                    0.44
# yun                          0.54            0.53                    0.43
# tai                          0.54            0.76                    0.61
# ai                           0.54            0.60                    0.44
# yong                         0.54            0.68                    0.49
# zhen                         0.54            0.56                    0.38
# sui                          0.54            0.71                    0.52
# yu                           0.54            0.20                    0.11
# ju                           0.53            0.37                    0.19
# jian                         0.53            0.35                    0.29
# tiao                         0.53            0.87                    0.76
# tao                          0.53            0.85                    0.73
# su                           0.53            0.52                    0.33
# chou                         0.53            0.59                    0.43
# zhou                         0.53            0.48                    0.37
# yang                         0.53            0.66                    0.51
# jiao                         0.53            0.32                    0.23
# fei                          0.52            0.82                    0.70
# dian                         0.52            0.68                    0.52
# min                          0.52            0.83                    0.71
# hu                           0.52            0.66                    0.47
# ge                           0.52            0.44                    0.29
# ao                           0.51            0.44                    0.36
# ming                         0.51            0.85                    0.73
# dun                          0.51            0.67                    0.48
# bing                         0.51            0.63                    0.44
# hao                          0.50            0.64                    0.48
# tu                           0.50            0.62                    0.42
# gou                          0.50            0.79                    0.66
# er                           0.50            0.83                    0.71
# jie                          0.50            0.30                    0.15
# shao                         0.50            0.81                    0.68
# pan                          0.50            0.81                    0.68
# cai                          0.50            0.81                    0.68
# ke                           0.50            0.48                    0.28
# tian                         0.49            0.80                    0.66
# ti                           0.49            0.59                    0.39
# ci                           0.49            0.63                    0.47
# qing                         0.49            0.42                    0.33
# geng                         0.48            0.82                    0.69
# kui                          0.48            0.64                    0.47
# bu                           0.48            0.50                    0.34
# ping                         0.48            0.50                    0.34
# tuo                          0.48            0.39                    0.27
# quan                         0.47            0.48                    0.36
# zi                           0.47            0.76                    0.61
# e                            0.47            0.34                    0.21
# hun                          0.47            0.67                    0.47
# xiu                          0.47            0.50                    0.37
# juan                         0.47            0.50                    0.29
# dan                          0.47            0.97                    0.94
# guang                        0.47            0.80                    0.66
# qu                           0.47            0.31                    0.17
# zhan                         0.46            0.39                    0.23
# lin                          0.46            0.96                    0.93
# zhu                          0.46            0.25                    0.13
# die                          0.46            0.50                    0.32
# cong                         0.46            0.77                    0.62
# tan                          0.46            0.77                    0.62
# meng                         0.46            0.47                    0.32
# lian                         0.46            0.96                    0.92
# mi                           0.46            0.38                    0.19
# chuang                       0.46            0.67                    0.49
# qiu                          0.46            0.52                    0.44
# xie                          0.46            0.24                    0.13
# bei                          0.46            0.36                    0.23
# mei                          0.45            0.36                    0.29
# cui                          0.45            0.38                    0.31
# ye                           0.45            0.38                    0.23
# suo                          0.45            0.70                    0.52
# du                           0.45            0.46                    0.34
# gan                          0.45            0.95                    0.90
# song                         0.45            0.67                    0.48
# qin                          0.45            0.55                    0.43
# xiang                        0.45            0.39                    0.25
# kan                          0.45            0.95                    0.90
# gao                          0.45            0.95                    0.90
# gai                          0.44            0.78                    0.63
# chang                        0.44            0.58                    0.42
# jue                          0.44            0.38                    0.22
# liang                        0.44            0.94                    0.89
# xuan                         0.44            0.57                    0.41
# shan                         0.44            0.45                    0.33
# jun                          0.44            0.57                    0.38
# zong                         0.44            0.64                    0.44
# jiong                        0.43            0.93                    0.88
# que                          0.43            0.53                    0.33
# nian                         0.43            0.58                    0.39
# biao                         0.43            0.93                    0.88
# xu                           0.43            0.20                    0.12
# lang                         0.43            0.93                    0.87
# zhuo                         0.43            0.44                    0.27
# bian                         0.43            0.68                    0.54
# xun                          0.43            0.32                    0.24
# gang                         0.43            0.93                    0.87
# miao                         0.42            0.73                    0.57
# zan                          0.42            0.73                    0.57
# mu                           0.42            0.47                    0.33
# hou                          0.42            0.92                    0.86
# he                           0.42            0.22                    0.13
# man                          0.42            0.69                    0.54
# pao                          0.42            0.92                    0.85
# ba                           0.42            0.39                    0.23
# pei                          0.41            0.69                    0.54
# zai                          0.41            0.91                    0.83
# long                         0.41            0.67                    0.52
# shu                          0.40            0.18                    0.10
# zu                           0.40            0.55                    0.36
# chuan                        0.40            0.60                    0.40
# pin                          0.40            0.90                    0.82
# chui                         0.40            0.60                    0.42
# ou                           0.40            0.60                    0.42
# ta                           0.40            0.55                    0.36
# zhao                         0.40            0.53                    0.34
# mo                           0.40            0.21                    0.14
# xin                          0.40            0.47                    0.40
# hua                          0.40            0.50                    0.30
# zha                          0.40            0.39                    0.21
# ren                          0.39            0.65                    0.51
# lv                           0.39            0.37                    0.22
# shang                        0.39            0.89                    0.80
# zun                          0.39            0.89                    0.80
# nao                          0.39            0.50                    0.31
# lie                          0.39            0.55                    0.39
# xing                         0.38            0.30                    0.26
# guo                          0.38            0.53                    0.38
# xia                          0.38            0.50                    0.32
# mou                          0.38            0.71                    0.55
# pai                          0.38            0.71                    0.55
# dui                          0.38            0.71                    0.55
# dou                          0.38            0.64                    0.50
# zhe                          0.38            0.35                    0.18
# rong                         0.38            0.44                    0.27
# mian                         0.38            0.44                    0.39
# tun                          0.38            0.62                    0.44
# lei                          0.38            0.45                    0.38
# heng                         0.38            0.62                    0.44
# can                          0.38            0.88                    0.78
# luo                          0.37            0.61                    0.49
# lao                          0.37            0.67                    0.51
# feng                         0.37            0.60                    0.48
# chen                         0.37            0.65                    0.50
# po                           0.37            0.46                    0.37
# chao                         0.37            0.54                    0.37
# cun                          0.36            0.56                    0.38
# ding                         0.36            0.62                    0.48
# gui                          0.36            0.65                    0.49
# rou                          0.36            0.86                    0.76
# kao                          0.36            0.86                    0.76
# rao                          0.36            0.86                    0.76
# beng                         0.36            0.86                    0.76
# pang                         0.36            0.86                    0.76
# cang                         0.36            0.86                    0.76
# nai                          0.36            0.56                    0.36
# tui                          0.36            0.56                    0.36
# she                          0.35            0.38                    0.24
# ni                           0.35            0.35                    0.18
# pu                           0.35            0.26                    0.20
# wo                           0.35            0.28                    0.17
# qiang                        0.35            0.36                    0.29
# dao                          0.34            0.84                    0.73
# sha                          0.34            0.41                    0.23
# ben                          0.33            0.83                    0.72
# zhun                         0.33            0.62                    0.47
# chun                         0.33            0.42                    0.28
# chai                         0.33            0.67                    0.50
# ran                          0.33            0.67                    0.50
# cuo                          0.33            0.42                    0.28
# de                           0.33            0.67                    0.50
# sheng                        0.33            0.56                    0.46
# gen                          0.33            0.67                    0.50
# xiong                        0.33            0.50                    0.35
# zhuang                       0.33            0.36                    0.29
# se                           0.32            0.57                    0.39
# zhai                         0.32            0.57                    0.39
# huai                         0.32            0.57                    0.39
# ma                           0.32            0.40                    0.28
# mang                         0.32            0.82                    0.70
# bin                          0.31            0.81                    0.70
# kong                         0.31            0.50                    0.34
# zhui                         0.31            0.33                    0.21
# zuo                          0.31            0.36                    0.22
# chong                        0.31            0.36                    0.22
# wen                          0.31            0.32                    0.22
# bai                          0.31            0.44                    0.33
# zhang                        0.31            0.58                    0.44
# hai                          0.30            0.55                    0.44
# sou                          0.30            0.64                    0.47
# weng                         0.30            0.80                    0.68
# sai                          0.30            0.80                    0.68
# men                          0.30            0.80                    0.68
# cuan                         0.30            0.80                    0.68
# ning                         0.30            0.50                    0.34
# qiao                         0.30            0.38                    0.26
# fa                           0.30            0.45                    0.32
# bang                         0.29            0.50                    0.45
# cu                           0.29            0.42                    0.22
# gua                          0.29            0.36                    0.26
# ku                           0.29            0.36                    0.26
# cheng                        0.29            0.21                    0.16
# qie                          0.29            0.36                    0.21
# nan                          0.29            0.57                    0.43
# duo                          0.29            0.33                    0.19
# huo                          0.28            0.47                    0.32
# chu                          0.27            0.15                    0.08
# ya                           0.27            0.36                    0.25
# zhong                        0.27            0.26                    0.21
# zhuan                        0.27            0.77                    0.64
# lou                          0.27            0.77                    0.64
# shun                         0.27            0.60                    0.44
# cha                          0.27            0.33                    0.25
# tong                         0.27            0.50                    0.42
# nie                          0.26            0.27                    0.21
# ru                           0.26            0.36                    0.24
# zeng                         0.25            0.38                    0.31
# zang                         0.25            0.43                    0.31
# shuo                         0.25            0.43                    0.31
# kuo                          0.25            0.50                    0.41
# zui                          0.25            0.50                    0.33
# yue                          0.25            0.38                    0.31
# duan                         0.25            0.50                    0.41
# ze                           0.24            0.33                    0.21
# zheng                        0.24            0.25                    0.20
# ling                         0.23            0.73                    0.61
# da                           0.23            0.30                    0.20
# tie                          0.23            0.43                    0.27
# wan                          0.22            0.28                    0.19
# zou                          0.22            0.50                    0.39
# ruo                          0.22            0.50                    0.39
# la                           0.22            0.33                    0.23
# niao                         0.22            0.50                    0.39
# chuo                         0.22            0.33                    0.23
# shou                         0.21            0.36                    0.30
# chan                         0.20            0.36                    0.28
# mie                          0.20            0.75                    0.62
# pou                          0.20            0.75                    0.62
# che                          0.19            0.43                    0.39
# nong                         0.19            0.38                    0.28
# sa                           0.17            0.29                    0.22
# xue                          0.17            0.20                    0.16
# dong                         0.17            0.67                    0.56
# qiong                        0.17            0.50                    0.38
# tou                          0.17            0.67                    0.56
# kai                          0.17            0.67                    0.56
# wa                           0.17            0.17                    0.12
# sun                          0.17            0.67                    0.56
# gong                         0.16            0.43                    0.37
# fang                         0.15            0.65                    0.54
# rui                          0.13            0.31                    0.27
# ang                          0.13            0.50                    0.38
# ken                          0.13            0.50                    0.38
# za                           0.13            0.40                    0.36
# ruan                         0.13            0.50                    0.38
# wang                         0.12            0.44                    0.35
# mai                          0.11            0.29                    0.27
# luan                         0.10            0.60                    0.52
# shui                         0.10            0.60                    0.52
# kua                          0.10            0.60                    0.52
# wai                          0.10            0.67                    0.56
# ceng                         0.10            0.67                    0.56
# ka                           0.10            0.67                    0.56
# pen                          0.10            0.67                    0.56
# shuai                        0.10            0.67                    0.56
# leng                         0.10            0.67                    0.56
# shai                         0.10            0.67                    0.56
# jiang                        0.09            0.41                    0.34
# ce                           0.08            0.33                    0.26
# kuang                        0.07            0.57                    0.51
# lun                          0.06            0.56                    0.51
# nei                          0.00            0.50                    0.50
# neng                         0.00            1.00                    1.00
# qun                          0.00            0.25                    0.25
# nen                          0.00            0.50                    0.50
# chuai                        0.00            0.50                    0.50
# rang                         0.00            1.00                    1.00
# kuai                         0.00            1.00                    1.00
# niu                          0.00            0.33                    0.33
# zen                          0.00            1.00                    1.00
# zei                          0.00            1.00                    1.00
# re                           0.00            0.50                    0.50
# cou                          0.00            1.00                    1.00
# ne                           0.00            0.50                    0.50
# reng                         0.00            1.00                    1.00
# ri                           0.00            0.50                    0.50
# nang                         0.00            0.50                    0.50
# run                          0.00            1.00                    1.00
# niang                        0.00            1.00                    1.00
# nu                           0.00            1.00                    1.00
# nou                          0.00            1.00                    1.00
# ca                           0.00            0.50                    0.50
# o                            0.00            0.50                    0.50
# pian                         0.00            1.00                    1.00
# zuan                         0.00            1.00                    1.00
# piao                         0.00            1.00                    1.00
# pie                          0.00            1.00                    1.00
# nve                          0.00            1.00                    1.00
# bie                          0.00            1.00                    1.00
# cao                          0.00            1.00                    1.00
# qia                          0.00            0.50                    0.50
# cen                          0.00            1.00                    1.00
# nv                           0.00            0.50                    0.50
# zhuai                        0.00            1.00                    1.00
# zhua                         0.00            1.00                    1.00
# nuo                          0.00            0.50                    0.50
# nuan                         0.00            1.00                    1.00
# dang                         0.00            1.00                    1.00
# san                          0.00            1.00                    1.00
# sang                         0.00            1.00                    1.00
# deng                         0.00            1.00                    1.00
# kang                         0.00            1.00                    1.00
# shuan                        0.00            1.00                    1.00
# shuang                       0.00            1.00                    1.00
# lia                          0.00            1.00                    1.00
# le                           0.00            0.33                    0.33
# suan                         0.00            1.00                    1.00
# lan                          0.00            1.00                    1.00
# lai                          0.00            1.00                    1.00
# kei                          0.00            1.00                    1.00
# hei                          0.00            0.50                    0.50
# kun                          0.00            1.00                    1.00
# tuan                         0.00            1.00                    1.00
# keng                         0.00            1.00                    1.00
# kuan                         0.00            1.00                    1.00
# kou                          0.00            1.00                    1.00
# te                           0.00            1.00                    1.00
# pa                           0.00            1.00                    1.00
# hen                          0.00            1.00                    1.00
# hang                         0.00            1.00                    1.00
# diao                         0.00            1.00                    1.00
# fou                          0.00            0.50                    0.50
# diu                          0.00            1.00                    1.00
# teng                         0.00            1.00                    1.00
# sao                          0.00            1.00                    1.00
# na                           0.00            0.17                    0.17
# en                           0.00            1.00                    1.00
# sen                          0.00            1.00                    1.00
# seng                         0.00            1.00                    1.00
# miu                          0.00            1.00                    1.00
# shua                         0.00            1.00                    1.00
# ga                           0.00            0.50                    0.50
# gei                          0.00            1.00                    1.00
# lve                          0.00            1.00                    1.00
# guai                         0.00            1.00                    1.00
# guan                         0.00            1.00                    1.00
# gun                          0.00            1.00                    1.00
# ha                           0.00            0.50                    0.50
# a                            0.00            1.00                    1.00
#
#                                                       distribution
# toneless_pinyin
# fu               {'fu': 51, 'fuku': 20, 'futsu': 8, 'bu': 3, 'h...
# li               {'ri': 31, 'rei': 22, 'reki': 9, 'ritsu': 4, '...
# huan             {'kan': 23, 'en': 2, 'gyou': 1, 'gen': 1, 'gan...
# qi               {'ki': 41, 'sei': 9, 'kei': 6, 'kitsu': 5, 'sh...
# wei              {'i': 37, 'bi': 6, 'wai': 3, 'gi': 3, 'kai': 3...
# jin              {'kin': 27, 'shin': 9, 'jin': 5, 'sen': 2, 'ko...
# han                     {'kan': 26, 'gan': 2, 'yama': 1, 'zen': 1}
# shen             {'shin': 23, 'chin': 2, 'jin': 2, 'juu': 1, 's...
# you                         {'yuu': 35, 'yu': 5, 'u': 1, 'you': 1}
# gu               {'ko': 30, 'koku': 4, 'kotsu': 3, 'ka': 1, 'it...
# pi               {'hi': 25, 'heki': 7, 'bi': 4, 'hitsu': 1, 'sh...
# jia              {'ka': 25, 'kyou': 4, 'kou': 4, 'kai': 2, 'kat...
# huang                    {'kou': 25, 'ou': 3, 'kyou': 1, 'you': 1}
# fan              {'han': 21, 'bon': 3, 'ban': 2, 'ka': 1, 'hon'...
# ban                      {'han': 18, 'fun': 1, 'ben': 1, 'ban': 1}
# mao              {'bou': 18, 'byou': 3, 'mou': 1, 'mai': 1, 'mu...
# yuan             {'en': 26, 'gen': 9, 'in': 2, 'kan': 2, 'on': ...
# yi               {'i': 34, 'eki': 13, 'gi': 11, 'itsu': 8, 'ei'...
# yin              {'in': 30, 'gin': 11, 'on': 2, 'gon': 1, 'an': 1}
# yao              {'you': 25, 'kou': 4, 'yaku': 3, 'gyou': 2, 'c...
# di               {'tei': 21, 'teki': 10, 'shi': 5, 'chaku': 1, ...
# si               {'shi': 22, 'ji': 4, 'sei': 2, 'sai': 1, 'su': 1}
# fen                      {'fun': 19, 'han': 2, 'hin': 1, 'bun': 1}
# hong             {'kou': 16, 'un': 1, 'ou': 1, 'kin': 1, 'gou':...
# jiu              {'kyuu': 20, 'shuu': 3, 'ku': 3, 'ki': 1, 'shu...
# zhi              {'shi': 38, 'chi': 12, 'shitsu': 9, 'shoku': 5...
# ji               {'ki': 39, 'seki': 9, 'kyuu': 8, 'shuu': 8, 'k...
# shi              {'shi': 33, 'shoku': 8, 'sei': 6, 'ji': 6, 'sh...
# yan              {'en': 51, 'gen': 11, 'gan': 7, 'ken': 4, 'in'...
# dai              {'tai': 14, 'dai': 1, 'hou': 1, 'nuta': 1, 'ga...
# xian             {'sen': 22, 'ken': 18, 'kan': 9, 'gen': 6, 'sh...
# tang                     {'tou': 14, 'shou': 1, 'dou': 1, 'do': 1}
# xiao             {'shou': 18, 'kou': 10, 'gyou': 2, 'kyou': 2, ...
# hui              {'kai': 21, 'ki': 14, 'kei': 4, 'i': 4, 'e': 3...
# an                {'an': 14, 'gan': 2, 'en': 1, 'ou': 1, 'kan': 1}
# wu               {'go': 18, 'bu': 10, 'mu': 5, 'o': 5, 'fu': 2,...
# liao                             {'ryou': 18, 'rou': 1, 'riku': 1}
# zao                    {'sou': 15, 'zou': 2, 'shuu': 1, 'saku': 1}
# xi               {'ki': 23, 'kei': 15, 'seki': 12, 'shitsu': 4,...
# bi               {'hi': 26, 'hitsu': 13, 'hei': 12, 'heki': 4, ...
# ying             {'ei': 25, 'you': 7, 'ou': 6, 'kei': 2, 'kou':...
# bo               {'haku': 17, 'ha': 6, 'botsu': 4, 'hatsu': 2, ...
# lu               {'ro': 28, 'roku': 11, 'riku': 3, 'ryoku': 2, ...
# qian             {'ken': 18, 'sen': 16, 'kan': 6, 'zen': 2, 'za...
# peng                               {'hou': 16, 'bou': 1, 'hau': 1}
# chi              {'chi': 16, 'shi': 10, 'choku': 3, 'seki': 3, ...
# liu                               {'ryuu': 15, 'roku': 1, 'ru': 1}
# ting             {'tei': 13, 'chou': 3, 'jou': 1, 'kin': 1, 'ei...
# jing             {'kei': 16, 'sei': 13, 'kyou': 10, 'gou': 1, '...
# bao              {'hou': 14, 'ho': 3, 'haku': 2, 'bou': 1, 'bak...
# yun              {'un': 19, 'in': 14, 'you': 1, 'utsu': 1, 'gei...
# tai                       {'tai': 13, 'dai': 2, 'chi': 1, 'ta': 1}
# ai               {'ai': 15, 'gai': 7, 'ki': 1, 'gan': 1, 'wai': 1}
# yong             {'you': 21, 'ei': 4, 'yuu': 3, 'gyou': 2, 'yu'...
# zhen             {'shin': 18, 'chin': 6, 'tei': 5, 'ken': 1, 't...
# sui              {'sui': 12, 'sai': 1, 'ki': 1, 'se': 1, 'e': 1...
# yu               {'yu': 21, 'u': 17, 'yo': 16, 'gyo': 8, 'iku':...
# ju               {'kyo': 20, 'ku': 8, 'kiku': 5, 'so': 5, 'gu':...
# jian             {'ken': 24, 'sen': 23, 'kan': 17, 'san': 2, 'g...
# tiao                             {'chou': 13, 'jou': 1, 'shuu': 1}
# tao                                {'tou': 17, 'dou': 2, 'jou': 1}
# su               {'so': 14, 'shuku': 6, 'zoku': 2, 'soku': 2, '...
# chou             {'chuu': 13, 'shuu': 6, 'kyuu': 1, 'shou': 1, ...
# zhou             {'shuu': 12, 'chuu': 9, 'ju': 1, 'chiku': 1, '...
# yang                    {'you': 19, 'ou': 8, 'gyou': 1, 'shou': 1}
# jiao             {'kou': 14, 'kyou': 13, 'shou': 8, 'kaku': 3, ...
# fei                               {'hi': 23, 'hai': 4, 'futsu': 1}
# dian                    {'ten': 15, 'den': 5, 'jou': 1, 'chou': 1}
# min                                {'bin': 15, 'min': 2, 'bei': 1}
# hu               {'ko': 27, 'kotsu': 5, 'go': 4, 'koku': 4, 'ka...
# ge               {'kaku': 11, 'ka': 7, 'katsu': 2, 'kitsu': 1, ...
# ao               {'ou': 11, 'gou': 10, 'kou': 1, 'gyuu': 1, 'ik...
# ming                             {'mei': 11, 'myou': 1, 'beki': 1}
# dun              {'ton': 10, 'jun': 2, 'shun': 1, 'son': 1, 'do...
# bing             {'hei': 12, 'hyou': 3, 'byou': 2, 'rin': 1, 'h...
# hao                     {'kou': 14, 'gou': 6, 'mou': 1, 'kaku': 1}
# tu               {'to': 10, 'totsu': 2, 'do': 1, 'cho': 1, 'tok...
# gou                                  {'kou': 19, 'ku': 4, 'gu': 1}
# er                                   {'ji': 10, 'ni': 1, 'jin': 1}
# jie              {'kai': 14, 'ketsu': 8, 'setsu': 6, 'katsu': 4...
# shao                            {'shou': 13, 'shaku': 2, 'sou': 1}
# pan                                {'han': 13, 'ban': 2, 'man': 1}
# cai                                {'sai': 13, 'zai': 2, 'shi': 1}
# ke               {'ka': 12, 'kou': 4, 'koku': 3, 'kaku': 2, 'ky...
# tian                              {'ten': 12, 'den': 2, 'chin': 1}
# ti               {'tei': 16, 'tai': 3, 'teki': 3, 'i': 2, 'dai'...
# ci                        {'shi': 12, 'ji': 5, 'sei': 1, 'sai': 1}
# qing             {'kei': 10, 'sei': 9, 'kyou': 2, 'jou': 1, 'gy...
# geng                               {'kou': 9, 'kan': 1, 'kyou': 1}
# kui                         {'ki': 18, 'kai': 6, 'kei': 3, 'u': 1}
# bu               {'ho': 9, 'fu': 5, 'choku': 1, 'bo': 1, 'hou':...
# ping             {'hei': 9, 'hyou': 5, 'byou': 1, 'hou': 1, 'bi...
# tuo              {'da': 11, 'ta': 7, 'taku': 6, 'i': 1, 'sha': ...
# quan             {'ken': 11, 'sen': 8, 'kan': 2, 'zen': 1, 'shu...
# zi                                  {'shi': 28, 'ji': 7, 'sai': 2}
# e                {'gaku': 13, 'ga': 10, 'a': 4, 'aku': 3, 'yaku...
# hun              {'kon': 8, 'gon': 1, 'kan': 1, 'gun': 1, 'kun'...
# xiu              {'shuu': 9, 'kyuu': 6, 'hou': 1, 'kou': 1, 'sh...
# juan             {'ken': 10, 'en': 3, 'kan': 1, 'gen': 1, 'ten'...
# dan                                           {'tan': 29, 'ta': 1}
# guang                              {'kou': 8, 'gen': 1, 'kyou': 1}
# qu               {'ku': 11, 'kyo': 8, 'shu': 3, 'kya': 2, 'kuts...
# zhan             {'sen': 11, 'ten': 6, 'tan': 4, 'zan': 2, 'san...
# lin                                         {'rin': 27, 'chin': 1}
# zhu              {'shu': 12, 'cho': 9, 'chuu': 5, 'chiku': 4, '...
# die              {'chou': 9, 'tetsu': 4, 'jou': 2, 'setsu': 1, ...
# cong                              {'sou': 10, 'shou': 2, 'juu': 1}
# tan                                {'tan': 20, 'dan': 4, 'don': 2}
# meng             {'mou': 8, 'bou': 5, 'mu': 1, 'mei': 1, 'betsu...
# lian                                         {'ren': 24, 'rei': 1}
# mi               {'bi': 12, 'beki': 4, 'hitsu': 3, 'mitsu': 3, ...
# chuang                  {'sou': 8, 'shou': 2, 'tou': 1, 'chin': 1}
# qiu                   {'kyuu': 15, 'shuu': 12, 'shou': 1, 'gu': 1}
# xie              {'kai': 11, 'setsu': 7, 'sha': 7, 'kyou': 5, '...
# bei              {'hai': 9, 'hi': 6, 'bai': 4, 'bi': 2, 'hoku':...
# mei              {'bi': 10, 'bai': 10, 'mai': 5, 'botsu': 1, 'b...
# cui              {'sai': 8, 'sui': 8, 'zei': 2, 'sotsu': 1, 'sa...
# ye               {'ya': 10, 'you': 6, 'eki': 3, 'etsu': 2, 'gyo...
# suo                     {'sa': 7, 'sho': 1, 'saku': 1, 'shuku': 1}
# du               {'to': 11, 'toku': 8, 'doku': 3, 'do': 1, 'ja'...
# gan                                          {'kan': 19, 'kon': 1}
# song                   {'shou': 10, 'sou': 2, 'suu': 2, 'shuu': 1}
# qin                      {'kin': 11, 'shin': 7, 'go': 1, 'sen': 1}
# xiang            {'shou': 11, 'kyou': 7, 'kou': 4, 'sou': 2, 'j...
# kan                                          {'kan': 18, 'gan': 1}
# gao                                         {'kou': 18, 'koku': 1}
# gai                               {'gai': 7, 'katsu': 1, 'kai': 1}
# chang                  {'shou': 15, 'chou': 7, 'jou': 3, 'tou': 1}
# jue              {'ketsu': 10, 'kaku': 5, 'kutsu': 4, 'shaku': ...
# liang                                       {'ryou': 16, 'rou': 1}
# xuan                    {'ken': 21, 'sen': 10, 'gen': 5, 'kan': 1}
# shan             {'sen': 14, 'san': 10, 'zen': 4, 'en': 2, 'sak...
# jun              {'shun': 12, 'kun': 3, 'kin': 3, 'gun': 2, 'so...
# zong             {'sou': 7, 'shuu': 1, 'shu': 1, 'juu': 1, 'sho...
# jiong                                        {'kei': 14, 'kin': 1}
# que              {'kaku': 8, 'ketsu': 2, 'jaku': 2, 'kyaku': 1,...
# nian             {'nen': 7, 'juu': 2, 'ten': 1, 'ren': 1, 'den'...
# biao                                      {'hyou': 14, 'shaku': 1}
# xu               {'ku': 8, 'jo': 7, 'kyoku': 5, 'kyo': 5, 'sho'...
# lang                                         {'rou': 13, 'tou': 1}
# zhuo             {'taku': 7, 'shaku': 4, 'setsu': 1, 'soku': 1,...
# bian                               {'hen': 19, 'ben': 8, 'han': 1}
# xun              {'jun': 12, 'kun': 12, 'jin': 6, 'shun': 3, 'k...
# gang                                         {'kou': 13, 'gou': 1}
# miao                             {'byou': 8, 'baku': 2, 'myou': 1}
# zan                                {'san': 8, 'zan': 2, 'shin': 1}
# mu               {'bo': 8, 'boku': 5, 'moku': 2, 'maku': 1, 'bo...
# hou                                           {'kou': 12, 'go': 1}
# he               {'ka': 7, 'kaku': 7, 'katsu': 4, 'kou': 3, 'go...
# man                                 {'man': 11, 'ban': 4, 'en': 1}
# pao                                         {'hou': 11, 'haku': 1}
# ba               {'ha': 7, 'hatsu': 4, 'hachi': 2, 'hai': 1, 'h...
# pei                                  {'hai': 9, 'bai': 3, 'hi': 1}
# zai                                          {'sai': 10, 'zai': 1}
# long                             {'rou': 12, 'ryuu': 5, 'ryou': 1}
# shu              {'sho': 9, 'shuku': 6, 'shu': 6, 'so': 6, 'ju'...
# zu               {'so': 6, 'zoku': 2, 'sotsu': 1, 'sha': 1, 'so...
# chuan            {'sen': 6, 'kan': 1, 'den': 1, 'ten': 1, 'kou'...
# pin                                           {'hin': 9, 'hei': 1}
# chui                     {'sui': 6, 'tsui': 2, 'tai': 1, 'zui': 1}
# ou                            {'ou': 6, 'guu': 2, 'u': 1, 'gu': 1}
# ta               {'tou': 6, 'tatsu': 2, 'ta': 1, 'taku': 1, 'da...
# zhao             {'shou': 9, 'chou': 3, 'tou': 2, 'sou': 2, 'ka...
# mo               {'baku': 6, 'matsu': 6, 'mo': 4, 'ma': 3, 'hak...
# xin                       {'shin': 8, 'kin': 7, 'ki': 1, 'kei': 1}
# hua              {'ka': 8, 'kaku': 2, 'katsu': 2, 'ga': 2, 'wa'...
# zha              {'sa': 7, 'saku': 3, 'tou': 2, 'ta': 1, 'shi':...
# ren                               {'jin': 11, 'nin': 5, 'shin': 1}
# lv               {'ryo': 7, 'ro': 4, 'ru': 3, 'ritsu': 2, 'ri':...
# shang                                        {'shou': 8, 'jou': 1}
# zun                                           {'son': 8, 'jun': 1}
# nao              {'dou': 6, 'nou': 2, 'do': 1, 'shaku': 1, 'ji'...
# lie                  {'retsu': 6, 'ryou': 3, 'rachi': 1, 'rei': 1}
# xing             {'kei': 7, 'sei': 7, 'kou': 6, 'kyou': 1, 'ei'...
# guo                    {'ka': 8, 'kaku': 4, 'koku': 2, 'katsu': 1}
# xia              {'ka': 11, 'kou': 4, 'kyou': 3, 'katsu': 3, 'k...
# mou                                 {'bou': 5, 'mu': 1, 'boku': 1}
# pai                                 {'hai': 5, 'haku': 1, 'ha': 1}
# dui                                 {'tai': 5, 'da': 1, 'tsui': 1}
# dou                                   {'tou': 9, 'to': 4, 'zu': 1}
# zhe              {'sha': 7, 'tetsu': 3, 'setsu': 2, 'taku': 2, ...
# rong             {'you': 7, 'ei': 3, 'jou': 2, 'juu': 2, 'kou':...
# mian                      {'men': 7, 'ben': 7, 'min': 1, 'bin': 1}
# tun                      {'ton': 5, 'don': 1, 'den': 1, 'chun': 1}
# lei                       {'rai': 9, 'rui': 8, 'roku': 2, 're': 1}
# heng                     {'kou': 5, 'kyou': 1, 'ou': 1, 'gyou': 1}
# can                                          {'san': 14, 'zan': 2}
# luo                                {'ra': 11, 'raku': 6, 'rui': 1}
# lao                                 {'rou': 6, 'raku': 2, 'bo': 1}
# feng                              {'hou': 12, 'fuu': 7, 'hyou': 1}
# chen                             {'shin': 13, 'chin': 5, 'jin': 2}
# po                       {'ha': 6, 'haku': 5, 'ba': 1, 'hachi': 1}
# chao                  {'chou': 7, 'sou': 3, 'shou': 2, 'shaku': 1}
# cun                      {'son': 5, 'shun': 2, 'tou': 1, 'sun': 1}
# ding                               {'tei': 8, 'chou': 4, 'jou': 1}
# gui                                 {'ki': 17, 'kei': 6, 'kai': 3}
# rou                                          {'juu': 6, 'niku': 1}
# kao                                           {'kou': 6, 'gou': 1}
# rao                                           {'jou': 6, 'dou': 1}
# beng                                         {'hou': 6, 'hyou': 1}
# pang                                          {'hou': 6, 'han': 1}
# cang                                          {'sou': 6, 'zou': 1}
# nai                {'dai': 5, 'no': 1, 'ji': 1, 'na': 1, 'tai': 1}
# tui              {'tai': 5, 'tatsu': 1, 'sui': 1, 'zei': 1, 'de...
# she              {'sha': 6, 'shou': 4, 'setsu': 2, 'ja': 2, 'ky...
# ni               {'gei': 7, 'ni': 2, 'ji': 2, 'deki': 2, 'jitsu...
# pu               {'boku': 6, 'ho': 6, 'fu': 5, 'baku': 2, 'bu':...
# wo               {'aku': 5, 'ka': 4, 'wa': 2, 'ga': 2, 'ta': 1,...
# qiang            {'shou': 8, 'kyou': 6, 'sou': 6, 'kou': 1, 'se...
# dao                                          {'tou': 16, 'dou': 3}
# sha              {'sa': 7, 'ka': 2, 'sou': 2, 'satsu': 2, 'shou...
# ben                                           {'hon': 5, 'fun': 1}
# zhun                              {'jun': 5, 'chun': 2, 'shun': 1}
# chun             {'jun': 5, 'shun': 3, 'shin': 2, 'chin': 1, 'd...
# chai                               {'sai': 4, 'taku': 1, 'shi': 1}
# ran                                 {'zen': 4, 'sen': 1, 'nen': 1}
# cuo              {'sa': 5, 'za': 3, 'saku': 2, 'so': 1, 'satsu'...
# de                                {'toku': 4, 'chi': 1, 'teki': 1}
# sheng                              {'sei': 9, 'shou': 6, 'jou': 1}
# gen                                 {'kon': 4, 'sen': 1, 'kou': 1}
# xiong                   {'kyou': 6, 'kei': 3, 'yuu': 2, 'kyuu': 1}
# zhuang           {'sou': 4, 'shou': 4, 'tou': 1, 'dou': 1, 'jou...
# se                {'shoku': 4, 'shuu': 1, 'shiki': 1, 'shitsu': 1}
# zhai                   {'sai': 4, 'taku': 1, 'teki': 1, 'saku': 1}
# huai                       {'kai': 4, 'hai': 1, 'wai': 1, 'ka': 1}
# ma                  {'ba': 4, 'ma': 3, 'bo': 1, 'shi': 1, 'me': 1}
# mang                                          {'bou': 9, 'mou': 2}
# bin                                          {'hin': 13, 'bin': 3}
# kong                      {'kou': 4, 'ku': 2, 'kyou': 1, 'kuu': 1}
# zhui             {'tsui': 4, 'sui': 3, 'zui': 1, 'tei': 1, 'zei...
# zuo              {'saku': 5, 'sa': 3, 'za': 2, 'so': 2, 'sai': ...
# chong            {'chuu': 5, 'shou': 3, 'juu': 2, 'dou': 2, 'ch...
# wen              {'on': 6, 'bun': 5, 'mon': 3, 'fun': 2, 'bin':...
# bai                     {'haku': 4, 'hai': 3, 'he': 1, 'hyaku': 1}
# zhang                            {'shou': 14, 'chou': 7, 'jou': 3}
# hai                                 {'gai': 6, 'kai': 4, 'kan': 1}
# sou                                {'sou': 7, 'shuu': 2, 'shu': 2}
# weng                                             {'ou': 4, 'o': 1}
# sai                                           {'sai': 4, 'shi': 1}
# men                                           {'mon': 4, 'man': 1}
# cuan                                          {'san': 4, 'zan': 1}
# ning                     {'nei': 5, 'dou': 2, 'cho': 2, 'gyou': 1}
# qiao             {'shou': 9, 'kyou': 6, 'kou': 5, 'shuu': 2, 'g...
# fa                    {'batsu': 5, 'hatsu': 3, 'hou': 2, 'bou': 1}
# bang                                {'bou': 8, 'hou': 7, 'hin': 1}
# cu               {'so': 5, 'soku': 1, 'sotsu': 1, 'sou': 1, 'zo...
# gua              {'kai': 4, 'katsu': 3, 'ka': 2, 'ke': 1, 'kei'...
# ku               {'ko': 4, 'koku': 3, 'kutsu': 2, 'kachi': 1, '...
# cheng            {'tei': 6, 'sei': 6, 'tou': 5, 'shou': 4, 'jou...
# qie              {'kyou': 4, 'setsu': 2, 'sha': 1, 'shou': 1, '...
# nan                                 {'nan': 4, 'dan': 2, 'tan': 1}
# duo              {'ta': 4, 'tatsu': 2, 'da': 2, 'totsu': 1, 'sh...
# huo                    {'kaku': 8, 'ka': 4, 'katsu': 3, 'waku': 2}
# chu              {'sho': 4, 'cho': 3, 'jo': 3, 'so': 2, 'chiku'...
# ya                 {'ga': 9, 'a': 6, 'gai': 5, 'atsu': 3, 'ou': 2}
# zhong            {'shou': 5, 'shuu': 5, 'chuu': 4, 'chou': 2, '...
# zhuan                                        {'sen': 10, 'ten': 3}
# lou                                           {'rou': 10, 'ru': 3}
# shun                               {'shun': 3, 'sen': 1, 'jun': 1}
# cha              {'ta': 4, 'sa': 3, 'sou': 3, 'satsu': 1, 'cha'...
# tong                              {'tou': 10, 'dou': 8, 'tsuu': 2}
# nie              {'shou': 3, 'getsu': 3, 'jou': 2, 'gou': 1, 'd...
# ru               {'joku': 5, 'ju': 3, 'jo': 3, 'nyuu': 2, 'zen'...
# zeng                     {'zou': 3, 'sou': 3, 'shou': 1, 'tou': 1}
# zang                     {'sou': 3, 'zou': 2, 'jou': 1, 'shou': 1}
# shuo                {'saku': 3, 'shaku': 2, 'seki': 1, 'setsu': 1}
# kuo                            {'katsu': 4, 'kaku': 3, 'kachi': 1}
# zui                       {'sai': 3, 'shi': 1, 'zai': 1, 'sui': 1}
# yue                  {'etsu': 6, 'yaku': 6, 'getsu': 2, 'gaku': 2}
# duan                                {'tan': 4, 'dan': 3, 'don': 1}
# ze               {'saku': 3, 'soku': 2, 'taku': 1, 'shoku': 1, ...
# zheng            {'sou': 6, 'sei': 6, 'jou': 4, 'shou': 4, 'tei...
# ling                                        {'rei': 22, 'ryou': 8}
# da               {'tou': 3, 'datsu': 2, 'tatsu': 2, 'dai': 1, '...
# tie              {'tetsu': 3, 'shou': 1, 'chou': 1, 'sen': 1, '...
# wan              {'wan': 8, 'gan': 6, 'en': 5, 'ban': 5, 'kan':...
# zou                                  {'suu': 3, 'sou': 2, 'su': 1}
# ruo                            {'jaku': 3, 'nyaku': 2, 'netsu': 1}
# la               {'rou': 3, 'ratsu': 2, 'ra': 2, 'shaku': 1, 's...
# niao                              {'jou': 3, 'chou': 2, 'nyou': 1}
# chuo             {'taku': 3, 'tetsu': 2, 'saku': 2, 'setsu': 1,...
# shou                      {'shuu': 5, 'ju': 4, 'shu': 4, 'sou': 1}
# chan                    {'sen': 12, 'san': 10, 'ten': 7, 'zan': 4}
# mie                                       {'betsu': 3, 'metsu': 1}
# pou                                           {'hou': 3, 'bou': 1}
# che                              {'sha': 3, 'tetsu': 3, 'taku': 1}
# nong                      {'nou': 3, 'dou': 2, 'jou': 2, 'rou': 1}
# sa               {'sou': 2, 'satsu': 2, 'san': 1, 'sai': 1, 'sa...
# xue              {'gaku': 2, 'ketsu': 2, 'setsu': 2, 'saku': 1,...
# dong                                         {'tou': 10, 'dou': 5}
# qiong                             {'kei': 4, 'kyuu': 2, 'kyou': 2}
# tou                                          {'tou': 4, 'chuu': 2}
# kai                                           {'gai': 8, 'kai': 4}
# wa               {'otsu': 2, 'a': 2, 'wa': 2, 'ai': 1, 'ka': 1,...
# sun                                           {'son': 4, 'jun': 2}
# gong                              {'kou': 9, 'kyou': 8, 'kyuu': 4}
# fang                                         {'hou': 11, 'bou': 6}
# rui                        {'zei': 4, 'zui': 4, 'ei': 3, 'sui': 2}
# ang                                 {'kou': 2, 'gyou': 1, 'ou': 1}
# ken                                 {'kon': 2, 'kou': 1, 'gin': 1}
# za                               {'satsu': 2, 'sou': 2, 'saku': 1}
# ruan                                {'zen': 2, 'nan': 1, 'gen': 1}
# wang                                 {'ou': 7, 'bou': 5, 'mou': 4}
# mai                    {'mai': 2, 'myaku': 2, 'bai': 2, 'baku': 1}
# luan                                          {'ran': 6, 'ren': 4}
# shui                                          {'sui': 3, 'zei': 2}
# kua                                             {'ko': 3, 'ka': 2}
# wai                                           {'wai': 2, 'gai': 1}
# ceng                                           {'sou': 2, 'so': 1}
# ka                                            {'ka': 2, 'kaku': 1}
# pen                                           {'fun': 2, 'bon': 1}
# shuai                                      {'sui': 2, 'shutsu': 1}
# leng                                         {'ryou': 2, 'rei': 1}
# shai                                          {'shi': 2, 'sai': 1}
# jiang                             {'kyou': 9, 'shou': 7, 'kou': 6}
# ce                    {'soku': 3, 'satsu': 2, 'shi': 2, 'saku': 2}
# kuang                                        {'kyou': 8, 'kou': 6}
# lun                                           {'rin': 5, 'ron': 4}
# nei                                           {'nai': 1, 'dai': 1}
# neng                                                    {'nou': 1}
# qun                      {'kin': 1, 'gun': 1, 'kun': 1, 'shun': 1}
# nen                                           {'don': 1, 'jin': 1}
# chuai                                       {'setsu': 1, 'shi': 1}
# rang                                                    {'jou': 7}
# kuai                                                    {'kai': 7}
# niu                              {'jiku': 1, 'gyuu': 1, 'chuu': 1}
# zen                                                    {'shin': 1}
# zei                                                    {'zoku': 1}
# re                                         {'jaku': 1, 'netsu': 1}
# cou                                                     {'sou': 4}
# ne                                           {'ji': 1, 'totsu': 1}
# reng                                                    {'jou': 2}
# ri                                        {'nichi': 1, 'jitsu': 1}
# nang                                          {'nou': 1, 'dou': 1}
# run                                                     {'jun': 2}
# niang                                                   {'jou': 3}
# nu                                                       {'do': 7}
# nou                                                     {'dou': 1}
# ca                                          {'sou': 1, 'satsu': 1}
# o                                              {'ga': 1, 'aku': 1}
# pian                                                    {'hen': 9}
# zuan                                                    {'san': 3}
# piao                                                  {'hyou': 11}
# pie                                                   {'betsu': 1}
# nve                                                   {'gyaku': 2}
# bie                                                   {'betsu': 3}
# cao                                                    {'sou': 10}
# qia                                         {'katsu': 1, 'kou': 1}
# cen                                                    {'shin': 2}
# nv                                            {'jo': 1, 'jiku': 1}
# zhuai                                                    {'ei': 1}
# zhua                                                     {'sa': 1}
# nuo                                           {'da': 1, 'daku': 1}
# nuan                                                    {'dan': 3}
# dang                                                   {'tou': 13}
# san                                                     {'san': 7}
# sang                                                    {'sou': 3}
# deng                                                   {'tou': 11}
# kang                                                   {'kou': 11}
# shuan                                                   {'sen': 1}
# shuang                                                  {'sou': 6}
# lia                                                    {'ryou': 1}
# le                               {'ryou': 1, 'gaku': 1, 'roku': 1}
# suan                                                    {'san': 4}
# lan                                                    {'ran': 22}
# lai                                                    {'rai': 12}
# kei                                                    {'koku': 1}
# hei                                         {'moku': 1, 'koku': 1}
# kun                                                    {'kon': 17}
# tuan                                                    {'tan': 4}
# keng                                                    {'kou': 3}
# kuan                                                    {'kan': 4}
# kou                                                     {'kou': 7}
# te                                                     {'toku': 3}
# pa                                                       {'ha': 6}
# hen                                                     {'kon': 3}
# hang                                                    {'kou': 5}
# diao                                                  {'chou': 14}
# fou                                            {'hi': 1, 'kan': 1}
# diu                                                    {'chuu': 1}
# teng                                                    {'tou': 8}
# sao                                                     {'sou': 8}
# na               {'totsu': 1, 'jo': 1, 'natsu': 1, 'nou': 1, 'd...
# en                                                       {'on': 1}
# sen                                                    {'shin': 1}
# seng                                                    {'sou': 2}
# miu                                                    {'byuu': 1}
# shua                                                  {'satsu': 1}
# ga                                        {'katsu': 1, 'kachi': 1}
# gei                                                    {'kyuu': 1}
# lve                                                   {'ryaku': 3}
# guai                                                    {'kai': 5}
# guan                                                   {'kan': 24}
# gun                                                     {'kon': 5}
# ha                                            {'gou': 1, 'kou': 1}
# a                                                         {'a': 2}
